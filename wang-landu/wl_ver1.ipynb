# %%
from numpy import *
from numpy import random
from numba import jit
import matplotlib.pyplot as plt

# %% [markdown]
# #### Randomize lattice and calculate energy
# $H = -\sum_{<r, r'>} S_r S_{r'}$

# %%
@jit(nopython=True)
def CEnergy(latt):
    N = shape(latt)[0]
    Ene = 0
    for i in range(len(latt)):
        for j in range(len(latt)):
            S = latt[i,j]  
            WF = latt[(i+1)%N,j]+latt[i,(j+1)%N]+latt[(i-1)%N,j]+latt[i,(j-1)%N]
            Ene += -S * WF
    return Ene/2.

def RandomL(N):
    return array(sign(2*random.random((N,N))-1),dtype=int)

# %% [markdown]
# #### Energy range $[-2N^2, -2N^2 + 4, ..., 2N^2]$

# %%
def PrepareEnergies(N):
    Energies = (array(4*arange(-int(N*N/2),int(N*N/2)+1),dtype=int)).tolist()
    Energies.pop(1)  
    Energies.pop(-2) 
    Energies = array(Energies) 
    Emin, Emax = Energies[0],Energies[-1]
    
    indE = -ones(Emax+1-Emin, dtype=int)
    for i,E in enumerate(Energies):
        indE[E-Emin]=i
    return (Energies, indE, Emin)

# %% [markdown]
# #### Wang Landau

# %%
from numpy import random
def WangLandau(Nitt, N, flatness):
    (Energies, indE, Emin) = PrepareEnergies(N)
    latt = RandomL(N)
    (lngE, Hist) = RunWangLandau(Nitt,Energies,latt,indE)
    return (Energies,lngE, Hist)

@jit(nopython=True)
def RunWangLandau(Nitt,Energies,latt,indE):
    N   = len(latt)
    Ene = int(CEnergy(latt))
    Emin, Emax = Energies[0],Energies[-1]
    # Logarithm of the density of states
    lngE = zeros(len(Energies))
    # Histogram
    Hist = zeros(len(Energies))
    # modification factor
    lnf = 1.0   # f = exp(lnf)=e
    N2 = N*N
    for itt in range(Nitt):
        t = int(random.rand()*N2)
        (i, j) = (int(t/N), t%N)
        S = latt[i,j]
        WF = latt[(i+1)%N,j]+latt[i,(j+1)%N]+latt[(i-1)%N,j]+latt[i,(j-1)%N]
        Enew = Ene + int(2*S*WF) 
        # P = g(E)/g(Enew) = exp(log(g(E))-log(g(Enew)))
        # P = exp(lngE(E)-lngE(Enew))
        lgnew = lngE[indE[Enew-Emin]] # log(g(Enew))
        lgold = lngE[indE[Ene-Emin]]  # log(g(Eold))
        P = 1.0
        if lgold-lgnew < 0 : P=exp(lgold-lgnew) # P = g_old/g_new = exp(log(g_old)-log(g_new))
        if P > random.rand():
            # accept the step
            latt[i,j] = -S
            Ene = Enew
        Hist[indE[Ene-Emin]] += 1
        lngE[indE[Ene-Emin]] += lnf   # g(E) -> g(E)*f hence log(g(E)) -> log(g(E))+log(f)
        
        if (itt+1) % 1000 == 0: # checking for flatness of the histogram
            aH = sum(Hist)/N2 # average
            mH = min(Hist)
            if mH > aH*flatness:  # histogram is flat
                Hist[:] = 0
                lnf /= 2.
                print(itt, 'histogram is flat', mH, aH, 'f=', exp(lnf))
    return (lngE, Hist)

# %%
from numpy import random

flatness = 0.92
N = 4
Nitt = int(10e8)

(Energies, lngE, Hist) = WangLandau(Nitt, N, flatness)
print('Done')
# Out:
# 4999 histogram is flat 309.0 312.5 f= 1.6487212707001282
# 7999 histogram is flat 179.0 187.5 f= 1.2840254166877414
# 12999 histogram is flat 299.0 312.5 f= 1.1331484530668263
# 19999 histogram is flat 399.0 437.5 f= 1.0644944589178593
# 23999 histogram is flat 231.0 250.0 f= 1.0317434074991028
# 28999 histogram is flat 287.0 312.5 f= 1.0157477085866857
# 35999 histogram is flat 433.0 437.5 f= 1.007843097206448
# 45999 histogram is flat 573.0 625.0 f= 1.0039138893383475
# 57999 histogram is flat 693.0 750.0 f= 1.0019550335910028
# 62999 histogram is flat 289.0 312.5 f= 1.0009770394924165
# 104999 histogram is flat 2556.0 2625.0 f= 1.0004884004786945
# 134999 histogram is flat 1718.0 1875.0 f= 1.0002441704297478
# 147999 histogram is flat 768.0 812.5 f= 1.0001220777633837
# 170999 histogram is flat 1343.0 1437.5 f= 1.0000610370189331
# 199999 histogram is flat 1669.0 1812.5 f= 1.000030518043791
# 222999 histogram is flat 1318.0 1437.5 f= 1.0000152589054785
# 250999 histogram is flat 1594.0 1750.0 f= 1.000007629423635
# 299999 histogram is flat 2788.0 3062.5 f= 1.0000038147045416
# 376999 histogram is flat 4411.0 4812.5 f= 1.0000019073504518
# 540999 histogram is flat 9337.0 10250.0 f= 1.0000009536747712
# 562999 histogram is flat 1275.0 1375.0 f= 1.000000476837272
# 571999 histogram is flat 513.0 562.5 f= 1.0000002384186075
# 581999 histogram is flat 575.0 625.0 f= 1.0000001192092967
# 593999 histogram is flat 688.0 750.0 f= 1.0000000596046466
# 610999 histogram is flat 971.0 1062.5 f= 1.0000000298023228
# 628999 histogram is flat 1057.0 1125.0 f= 1.0000000149011612
# 644999 histogram is flat 941.0 1000.0 f= 1.0000000074505806
# 665999 histogram is flat 1209.0 1312.5 f= 1.0000000037252903
# 683999 histogram is flat 1024.0 1125.0 f= 1.0000000018626451
# 700999 histogram is flat 994.0 1062.5 f= 1.0000000009313226
# 716999 histogram is flat 911.0 1000.0 f= 1.0000000004656613
# 768999 histogram is flat 2961.0 3250.0 f= 1.0000000002328306
# 791999 histogram is flat 1337.0 1437.5 f= 1.0000000001164153
# 809999 histogram is flat 1035.0 1125.0 f= 1.0000000000582077
# 827999 histogram is flat 1029.0 1125.0 f= 1.0000000000291038
# 861999 histogram is flat 1941.0 2125.0 f= 1.000000000014552
# 884999 histogram is flat 1351.0 1437.5 f= 1.000000000007276
# 920999 histogram is flat 2059.0 2250.0 f= 1.000000000003638
# 942999 histogram is flat 1269.0 1375.0 f= 1.000000000001819
# 976999 histogram is flat 1948.0 2125.0 f= 1.0000000000009095
# 994999 histogram is flat 1027.0 1125.0 f= 1.0000000000004547
# 1103999 histogram is flat 6237.0 6812.5 f= 1.0000000000002274
# 1125999 histogram is flat 1264.0 1375.0 f= 1.0000000000001137
# 1147999 histogram is flat 1281.0 1375.0 f= 1.0000000000000568
# 1172999 histogram is flat 1439.0 1562.5 f= 1.0000000000000284
# 1179999 histogram is flat 417.0 437.5 f= 1.0000000000000142
# 1220999 histogram is flat 2376.0 2562.5 f= 1.000000000000007
# 1246999 histogram is flat 1488.0 1625.0 f= 1.0000000000000036
# 1253999 histogram is flat 405.0 437.5 f= 1.0000000000000018
# 1278999 histogram is flat 1422.0 1562.5 f= 1.0000000000000009
# 1304999 histogram is flat 1541.0 1625.0 f= 1.0000000000000004
# 1313999 histogram is flat 519.0 562.5 f= 1.0000000000000002
# 1358999 histogram is flat 2583.0 2812.5 f= 1.0
# 1416999 histogram is flat 3303.0 3625.0 f= 1.0
# 1458999 histogram is flat 2440.0 2625.0 f= 1.0
# 1507999 histogram is flat 2790.0 3062.5 f= 1.0
# 1527999 histogram is flat 1150.0 1250.0 f= 1.0
# 1548999 histogram is flat 1272.0 1312.5 f= 1.0
# 1602999 histogram is flat 3075.0 3375.0 f= 1.0
# 1646999 histogram is flat 2530.0 2750.0 f= 1.0
# 1660999 histogram is flat 829.0 875.0 f= 1.0
# 1689999 histogram is flat 1702.0 1812.5 f= 1.0
# 1724999 histogram is flat 1998.0 2187.5 f= 1.0
# 1758999 histogram is flat 1953.0 2125.0 f= 1.0
# 1785999 histogram is flat 1536.0 1687.5 f= 1.0
# 1830999 histogram is flat 2589.0 2812.5 f= 1.0
# 1885999 histogram is flat 3133.0 3437.5 f= 1.0
# 1921999 histogram is flat 2102.0 2250.0 f= 1.0
# 1962999 histogram is flat 2368.0 2562.5 f= 1.0
# 2024999 histogram is flat 3554.0 3875.0 f= 1.0
# 2049999 histogram is flat 1486.0 1562.5 f= 1.0
# 2077999 histogram is flat 1595.0 1750.0 f= 1.0
# 2107999 histogram is flat 1731.0 1875.0 f= 1.0
# 2128999 histogram is flat 1216.0 1312.5 f= 1.0
# 2140999 histogram is flat 687.0 750.0 f= 1.0
# 2196999 histogram is flat 3284.0 3500.0 f= 1.0
# 2222999 histogram is flat 1509.0 1625.0 f= 1.0
# 2256999 histogram is flat 1938.0 2125.0 f= 1.0
# 2299999 histogram is flat 2502.0 2687.5 f= 1.0
# 2325999 histogram is flat 1497.0 1625.0 f= 1.0
# 2379999 histogram is flat 3077.0 3375.0 f= 1.0
# 2402999 histogram is flat 1362.0 1437.5 f= 1.0
# 2426999 histogram is flat 1430.0 1500.0 f= 1.0
# 2468999 histogram is flat 2396.0 2625.0 f= 1.0
# 2534999 histogram is flat 3774.0 4125.0 f= 1.0
# 2552999 histogram is flat 1041.0 1125.0 f= 1.0
# 2565999 histogram is flat 742.0 812.5 f= 1.0
# 2618999 histogram is flat 3048.0 3312.5 f= 1.0
# 2635999 histogram is flat 972.0 1062.5 f= 1.0
# 2698999 histogram is flat 3603.0 3937.5 f= 1.0
# 2714999 histogram is flat 915.0 1000.0 f= 1.0
# 2734999 histogram is flat 1165.0 1250.0 f= 1.0
# 2753999 histogram is flat 1089.0 1187.5 f= 1.0
# 2946999 histogram is flat 11012.0 12062.5 f= 1.0
# 3017999 histogram is flat 4106.0 4437.5 f= 1.0
# 3039999 histogram is flat 1253.0 1375.0 f= 1.0
# 3064999 histogram is flat 1439.0 1562.5 f= 1.0
# 3086999 histogram is flat 1262.0 1375.0 f= 1.0
# 3124999 histogram is flat 2178.0 2375.0 f= 1.0
# 3146999 histogram is flat 1283.0 1375.0 f= 1.0
# 3162999 histogram is flat 935.0 1000.0 f= 1.0
# 3190999 histogram is flat 1621.0 1750.0 f= 1.0
# 3235999 histogram is flat 2621.0 2812.5 f= 1.0
# 3303999 histogram is flat 3878.0 4250.0 f= 1.0
# 3316999 histogram is flat 753.0 812.5 f= 1.0
# 3329999 histogram is flat 797.0 812.5 f= 1.0
# 3350999 histogram is flat 1208.0 1312.5 f= 1.0
# 3375999 histogram is flat 1437.0 1562.5 f= 1.0
# 3408999 histogram is flat 1882.0 2062.5 f= 1.0
# 3471999 histogram is flat 3646.0 3937.5 f= 1.0
# 3506999 histogram is flat 2017.0 2187.5 f= 1.0
# 3518999 histogram is flat 694.0 750.0 f= 1.0
# 3535999 histogram is flat 990.0 1062.5 f= 1.0
# 3585999 histogram is flat 2853.0 3125.0 f= 1.0
# 3620999 histogram is flat 1992.0 2187.5 f= 1.0
# 3680999 histogram is flat 3434.0 3750.0 f= 1.0
# 3747999 histogram is flat 3867.0 4187.5 f= 1.0
# 3751999 histogram is flat 230.0 250.0 f= 1.0
# 3762999 histogram is flat 630.0 687.5 f= 1.0
# 3805999 histogram is flat 2449.0 2687.5 f= 1.0
# 4015999 histogram is flat 11952.0 13125.0 f= 1.0
# 4037999 histogram is flat 1291.0 1375.0 f= 1.0
# 4064999 histogram is flat 1583.0 1687.5 f= 1.0
# 4076999 histogram is flat 705.0 750.0 f= 1.0
# 4092999 histogram is flat 934.0 1000.0 f= 1.0
# 4163999 histogram is flat 4050.0 4437.5 f= 1.0
# 4220999 histogram is flat 3267.0 3562.5 f= 1.0
# 4242999 histogram is flat 1254.0 1375.0 f= 1.0
# 4276999 histogram is flat 1942.0 2125.0 f= 1.0
# 4291999 histogram is flat 857.0 937.5 f= 1.0
# 4362999 histogram is flat 4115.0 4437.5 f= 1.0
# 4405999 histogram is flat 2450.0 2687.5 f= 1.0
# 4425999 histogram is flat 1179.0 1250.0 f= 1.0
# 4454999 histogram is flat 1663.0 1812.5 f= 1.0
# 4632999 histogram is flat 10172.0 11125.0 f= 1.0
# 4648999 histogram is flat 928.0 1000.0 f= 1.0
# 4674999 histogram is flat 1548.0 1625.0 f= 1.0
# 4696999 histogram is flat 1314.0 1375.0 f= 1.0
# 4808999 histogram is flat 6380.0 7000.0 f= 1.0
# 4823999 histogram is flat 890.0 937.5 f= 1.0
# 4839999 histogram is flat 927.0 1000.0 f= 1.0
# 4848999 histogram is flat 522.0 562.5 f= 1.0
# 4884999 histogram is flat 2102.0 2250.0 f= 1.0
# 4912999 histogram is flat 1618.0 1750.0 f= 1.0
# 4952999 histogram is flat 2276.0 2500.0 f= 1.0
# 5037999 histogram is flat 4900.0 5312.5 f= 1.0
# 5089999 histogram is flat 3010.0 3250.0 f= 1.0
# 5125999 histogram is flat 2067.0 2250.0 f= 1.0
# 5209999 histogram is flat 4808.0 5250.0 f= 1.0
# 5225999 histogram is flat 912.0 1000.0 f= 1.0
# 5501999 histogram is flat 15853.0 17250.0 f= 1.0
# 5618999 histogram is flat 6829.0 7312.5 f= 1.0
# 5740999 histogram is flat 6962.0 7625.0 f= 1.0
# 5780999 histogram is flat 2277.0 2500.0 f= 1.0
# 5851999 histogram is flat 4074.0 4437.5 f= 1.0
# 5877999 histogram is flat 1513.0 1625.0 f= 1.0
# 5908999 histogram is flat 1774.0 1937.5 f= 1.0
# 6094999 histogram is flat 10604.0 11625.0 f= 1.0
# 6115999 histogram is flat 1197.0 1312.5 f= 1.0
# 6133999 histogram is flat 1026.0 1125.0 f= 1.0
# 6139999 histogram is flat 349.0 375.0 f= 1.0
# 6163999 histogram is flat 1379.0 1500.0 f= 1.0
# 6184999 histogram is flat 1241.0 1312.5 f= 1.0
# 6207999 histogram is flat 1327.0 1437.5 f= 1.0
# 6232999 histogram is flat 1433.0 1562.5 f= 1.0
# 6252999 histogram is flat 1139.0 1250.0 f= 1.0
# 6282999 histogram is flat 1721.0 1875.0 f= 1.0
# 6349999 histogram is flat 3877.0 4187.5 f= 1.0
# 6361999 histogram is flat 710.0 750.0 f= 1.0
# 6376999 histogram is flat 855.0 937.5 f= 1.0
# 6404999 histogram is flat 1626.0 1750.0 f= 1.0
# 6433999 histogram is flat 1659.0 1812.5 f= 1.0
# 6486999 histogram is flat 3018.0 3312.5 f= 1.0
# 6493999 histogram is flat 403.0 437.5 f= 1.0
# 6514999 histogram is flat 1198.0 1312.5 f= 1.0
# 6537999 histogram is flat 1342.0 1437.5 f= 1.0
# 6550999 histogram is flat 754.0 812.5 f= 1.0
# 6564999 histogram is flat 825.0 875.0 f= 1.0
# 6617999 histogram is flat 3016.0 3312.5 f= 1.0
# 6633999 histogram is flat 931.0 1000.0 f= 1.0
# 6649999 histogram is flat 913.0 1000.0 f= 1.0
# 6678999 histogram is flat 1651.0 1812.5 f= 1.0
# 6688999 histogram is flat 582.0 625.0 f= 1.0
# 6752999 histogram is flat 3658.0 4000.0 f= 1.0
# 6768999 histogram is flat 913.0 1000.0 f= 1.0
# 6860999 histogram is flat 5243.0 5750.0 f= 1.0
# 6875999 histogram is flat 877.0 937.5 f= 1.0
# 6891999 histogram is flat 932.0 1000.0 f= 1.0
# 6908999 histogram is flat 972.0 1062.5 f= 1.0
# 6931999 histogram is flat 1331.0 1437.5 f= 1.0
# 6965999 histogram is flat 1971.0 2125.0 f= 1.0
# 6982999 histogram is flat 980.0 1062.5 f= 1.0
# 7052999 histogram is flat 4002.0 4375.0 f= 1.0
# 7136999 histogram is flat 4822.0 5250.0 f= 1.0
# 7146999 histogram is flat 570.0 625.0 f= 1.0
# 7189999 histogram is flat 2449.0 2687.5 f= 1.0
# 7224999 histogram is flat 2024.0 2187.5 f= 1.0
# 7282999 histogram is flat 3324.0 3625.0 f= 1.0
# 7292999 histogram is flat 579.0 625.0 f= 1.0
# 7311999 histogram is flat 1102.0 1187.5 f= 1.0
# 7339999 histogram is flat 1601.0 1750.0 f= 1.0
# 7358999 histogram is flat 1123.0 1187.5 f= 1.0
# 7450999 histogram is flat 5252.0 5750.0 f= 1.0
# 7468999 histogram is flat 1032.0 1125.0 f= 1.0
# 7491999 histogram is flat 1323.0 1437.5 f= 1.0
# 7499999 histogram is flat 469.0 500.0 f= 1.0
# 7563999 histogram is flat 3650.0 4000.0 f= 1.0
# 7618999 histogram is flat 3137.0 3437.5 f= 1.0
# 7810999 histogram is flat 10961.0 12000.0 f= 1.0
# 7851999 histogram is flat 2385.0 2562.5 f= 1.0
# 7870999 histogram is flat 1097.0 1187.5 f= 1.0
# 7942999 histogram is flat 4133.0 4500.0 f= 1.0
# 7971999 histogram is flat 1656.0 1812.5 f= 1.0
# 7986999 histogram is flat 876.0 937.5 f= 1.0
# 8007999 histogram is flat 1237.0 1312.5 f= 1.0
# 8098999 histogram is flat 5233.0 5687.5 f= 1.0
# 8116999 histogram is flat 1032.0 1125.0 f= 1.0
# 8123999 histogram is flat 402.0 437.5 f= 1.0
# 8231999 histogram is flat 6207.0 6750.0 f= 1.0
# 8268999 histogram is flat 2109.0 2312.5 f= 1.0
# 8524999 histogram is flat 14642.0 16000.0 f= 1.0
# 8552999 histogram is flat 1619.0 1750.0 f= 1.0
# 8571999 histogram is flat 1133.0 1187.5 f= 1.0
# 8597999 histogram is flat 1525.0 1625.0 f= 1.0
# 8676999 histogram is flat 4603.0 4937.5 f= 1.0
# 8798999 histogram is flat 7029.0 7625.0 f= 1.0
# 8805999 histogram is flat 399.0 437.5 f= 1.0
# 8877999 histogram is flat 4103.0 4500.0 f= 1.0
# 9143999 histogram is flat 15241.0 16625.0 f= 1.0
# 9166999 histogram is flat 1332.0 1437.5 f= 1.0
# 9187999 histogram is flat 1202.0 1312.5 f= 1.0
# 9214999 histogram is flat 1549.0 1687.5 f= 1.0
# 9224999 histogram is flat 602.0 625.0 f= 1.0
# 9233999 histogram is flat 534.0 562.5 f= 1.0
# 9244999 histogram is flat 642.0 687.5 f= 1.0
# 9293999 histogram is flat 2838.0 3062.5 f= 1.0
# 9343999 histogram is flat 2852.0 3125.0 f= 1.0
# 9368999 histogram is flat 1422.0 1562.5 f= 1.0
# 9424999 histogram is flat 3209.0 3500.0 f= 1.0
# 9464999 histogram is flat 2284.0 2500.0 f= 1.0
# 9490999 histogram is flat 1493.0 1625.0 f= 1.0
# 9518999 histogram is flat 1599.0 1750.0 f= 1.0
# 9536999 histogram is flat 1041.0 1125.0 f= 1.0
# 9554999 histogram is flat 1033.0 1125.0 f= 1.0
# 9742999 histogram is flat 10851.0 11750.0 f= 1.0
# 9756999 histogram is flat 816.0 875.0 f= 1.0
# 9795999 histogram is flat 2224.0 2437.5 f= 1.0
# 9837999 histogram is flat 2419.0 2625.0 f= 1.0
# 9987999 histogram is flat 8576.0 9375.0 f= 1.0
# 10001999 histogram is flat 801.0 875.0 f= 1.0
# 10022999 histogram is flat 1208.0 1312.5 f= 1.0
# 10046999 histogram is flat 1375.0 1500.0 f= 1.0
# 10059999 histogram is flat 743.0 812.5 f= 1.0
# 10084999 histogram is flat 1432.0 1562.5 f= 1.0
# 10120999 histogram is flat 2050.0 2250.0 f= 1.0
# 10206999 histogram is flat 4927.0 5375.0 f= 1.0
# 10231999 histogram is flat 1438.0 1562.5 f= 1.0
# 10267999 histogram is flat 2068.0 2250.0 f= 1.0
# 10278999 histogram is flat 629.0 687.5 f= 1.0
# 10358999 histogram is flat 4586.0 5000.0 f= 1.0
# 10365999 histogram is flat 400.0 437.5 f= 1.0
# 10440999 histogram is flat 4361.0 4687.5 f= 1.0
# 10577999 histogram is flat 7857.0 8562.5 f= 1.0
# 10661999 histogram is flat 4792.0 5250.0 f= 1.0
# 10683999 histogram is flat 1272.0 1375.0 f= 1.0
# 10697999 histogram is flat 801.0 875.0 f= 1.0
# 10744999 histogram is flat 2756.0 2937.5 f= 1.0
# 10755999 histogram is flat 642.0 687.5 f= 1.0
# 10799999 histogram is flat 2508.0 2750.0 f= 1.0
# 10831999 histogram is flat 1834.0 2000.0 f= 1.0
# 10849999 histogram is flat 1026.0 1125.0 f= 1.0
# 10958999 histogram is flat 6229.0 6812.5 f= 1.0
# 10974999 histogram is flat 946.0 1000.0 f= 1.0
# 11017999 histogram is flat 2454.0 2687.5 f= 1.0
# 11054999 histogram is flat 2182.0 2312.5 f= 1.0
# 11068999 histogram is flat 814.0 875.0 f= 1.0
# 11094999 histogram is flat 1509.0 1625.0 f= 1.0
# 11105999 histogram is flat 627.0 687.5 f= 1.0
# 11128999 histogram is flat 1395.0 1437.5 f= 1.0
# 11162999 histogram is flat 1962.0 2125.0 f= 1.0
# 11194999 histogram is flat 1831.0 2000.0 f= 1.0
# 11207999 histogram is flat 740.0 812.5 f= 1.0
# 11233999 histogram is flat 1486.0 1625.0 f= 1.0
# 11283999 histogram is flat 2856.0 3125.0 f= 1.0
# 11301999 histogram is flat 1047.0 1125.0 f= 1.0
# 11322999 histogram is flat 1196.0 1312.5 f= 1.0
# 11417999 histogram is flat 5447.0 5937.5 f= 1.0
# 11462999 histogram is flat 2576.0 2812.5 f= 1.0
# 11473999 histogram is flat 637.0 687.5 f= 1.0
# 11503999 histogram is flat 1737.0 1875.0 f= 1.0
# 11531999 histogram is flat 1597.0 1750.0 f= 1.0
# 11559999 histogram is flat 1610.0 1750.0 f= 1.0
# 11585999 histogram is flat 1479.0 1625.0 f= 1.0
# 11603999 histogram is flat 1024.0 1125.0 f= 1.0
# 11641999 histogram is flat 2177.0 2375.0 f= 1.0
# 11684999 histogram is flat 2525.0 2687.5 f= 1.0
# 11725999 histogram is flat 2346.0 2562.5 f= 1.0
# 11735999 histogram is flat 593.0 625.0 f= 1.0
# 11811999 histogram is flat 4359.0 4750.0 f= 1.0
# 11853999 histogram is flat 2458.0 2625.0 f= 1.0
# 11876999 histogram is flat 1331.0 1437.5 f= 1.0
# 11950999 histogram is flat 4279.0 4625.0 f= 1.0
# 11961999 histogram is flat 630.0 687.5 f= 1.0
# 11979999 histogram is flat 1051.0 1125.0 f= 1.0
# 11988999 histogram is flat 519.0 562.5 f= 1.0
# 12007999 histogram is flat 1133.0 1187.5 f= 1.0
# 12053999 histogram is flat 2689.0 2875.0 f= 1.0
# 12077999 histogram is flat 1368.0 1500.0 f= 1.0
# 12092999 histogram is flat 874.0 937.5 f= 1.0
# 12115999 histogram is flat 1344.0 1437.5 f= 1.0
# 12168999 histogram is flat 3033.0 3312.5 f= 1.0
# 12183999 histogram is flat 860.0 937.5 f= 1.0
# 12201999 histogram is flat 1033.0 1125.0 f= 1.0
# 12232999 histogram is flat 1764.0 1937.5 f= 1.0
# 12250999 histogram is flat 1075.0 1125.0 f= 1.0
# 12277999 histogram is flat 1545.0 1687.5 f= 1.0
# 12343999 histogram is flat 3802.0 4125.0 f= 1.0
# 12373999 histogram is flat 1726.0 1875.0 f= 1.0
# 12384999 histogram is flat 637.0 687.5 f= 1.0
# 12404999 histogram is flat 1154.0 1250.0 f= 1.0
# 12454999 histogram is flat 2858.0 3125.0 f= 1.0
# 12503999 histogram is flat 2815.0 3062.5 f= 1.0
# 12523999 histogram is flat 1170.0 1250.0 f= 1.0
# 12547999 histogram is flat 1453.0 1500.0 f= 1.0
# 12674999 histogram is flat 7276.0 7937.5 f= 1.0
# 12693999 histogram is flat 1113.0 1187.5 f= 1.0
# 12709999 histogram is flat 949.0 1000.0 f= 1.0
# 12729999 histogram is flat 1147.0 1250.0 f= 1.0
# 12768999 histogram is flat 2253.0 2437.5 f= 1.0
# 12775999 histogram is flat 402.0 437.5 f= 1.0
# 12815999 histogram is flat 2277.0 2500.0 f= 1.0
# 12827999 histogram is flat 701.0 750.0 f= 1.0
# 12852999 histogram is flat 1442.0 1562.5 f= 1.0
# 12926999 histogram is flat 4242.0 4625.0 f= 1.0
# 12950999 histogram is flat 1396.0 1500.0 f= 1.0
# 12990999 histogram is flat 2276.0 2500.0 f= 1.0
# 13011999 histogram is flat 1212.0 1312.5 f= 1.0
# 13024999 histogram is flat 751.0 812.5 f= 1.0
# 13049999 histogram is flat 1444.0 1562.5 f= 1.0
# 13059999 histogram is flat 589.0 625.0 f= 1.0
# 13080999 histogram is flat 1214.0 1312.5 f= 1.0
# 13093999 histogram is flat 764.0 812.5 f= 1.0
# 13130999 histogram is flat 2125.0 2312.5 f= 1.0
# 13145999 histogram is flat 872.0 937.5 f= 1.0
# 13159999 histogram is flat 805.0 875.0 f= 1.0
# 13204999 histogram is flat 2572.0 2812.5 f= 1.0
# 13225999 histogram is flat 1229.0 1312.5 f= 1.0
# 13248999 histogram is flat 1323.0 1437.5 f= 1.0
# 13266999 histogram is flat 1036.0 1125.0 f= 1.0
# 13327999 histogram is flat 3480.0 3812.5 f= 1.0
# 13357999 histogram is flat 1735.0 1875.0 f= 1.0
# 13386999 histogram is flat 1652.0 1812.5 f= 1.0
# 13425999 histogram is flat 2234.0 2437.5 f= 1.0
# 13467999 histogram is flat 2437.0 2625.0 f= 1.0
# 13493999 histogram is flat 1490.0 1625.0 f= 1.0
# 13525999 histogram is flat 1822.0 2000.0 f= 1.0
# 13574999 histogram is flat 2856.0 3062.5 f= 1.0
# 13631999 histogram is flat 3264.0 3562.5 f= 1.0
# 13698999 histogram is flat 3812.0 4187.5 f= 1.0
# 13708999 histogram is flat 570.0 625.0 f= 1.0
# 13722999 histogram is flat 800.0 875.0 f= 1.0
# 13746999 histogram is flat 1367.0 1500.0 f= 1.0
# 13904999 histogram is flat 8988.0 9875.0 f= 1.0
# 13926999 histogram is flat 1260.0 1375.0 f= 1.0
# 13983999 histogram is flat 3363.0 3562.5 f= 1.0
# 13993999 histogram is flat 604.0 625.0 f= 1.0
# 14038999 histogram is flat 2581.0 2812.5 f= 1.0
# 14050999 histogram is flat 712.0 750.0 f= 1.0
# 14106999 histogram is flat 3209.0 3500.0 f= 1.0
# 14118999 histogram is flat 694.0 750.0 f= 1.0
# 14148999 histogram is flat 1709.0 1875.0 f= 1.0
# 14163999 histogram is flat 867.0 937.5 f= 1.0
# 14177999 histogram is flat 805.0 875.0 f= 1.0
# 14206999 histogram is flat 1675.0 1812.5 f= 1.0
# 14232999 histogram is flat 1523.0 1625.0 f= 1.0
# 14327999 histogram is flat 5449.0 5937.5 f= 1.0
# 14409999 histogram is flat 4683.0 5125.0 f= 1.0
# 14447999 histogram is flat 2164.0 2375.0 f= 1.0
# 14672999 histogram is flat 12830.0 14062.5 f= 1.0
# 14688999 histogram is flat 911.0 1000.0 f= 1.0
# 14722999 histogram is flat 1991.0 2125.0 f= 1.0
# 14734999 histogram is flat 695.0 750.0 f= 1.0
# 14756999 histogram is flat 1310.0 1375.0 f= 1.0
# 14862999 histogram is flat 6083.0 6625.0 f= 1.0
# 14891999 histogram is flat 1668.0 1812.5 f= 1.0
# 14910999 histogram is flat 1098.0 1187.5 f= 1.0
# 14973999 histogram is flat 3651.0 3937.5 f= 1.0
# 15137999 histogram is flat 9405.0 10250.0 f= 1.0
# 15147999 histogram is flat 586.0 625.0 f= 1.0
# 15197999 histogram is flat 2860.0 3125.0 f= 1.0
# 15216999 histogram is flat 1094.0 1187.5 f= 1.0
# 15274999 histogram is flat 3308.0 3625.0 f= 1.0
# 15306999 histogram is flat 1845.0 2000.0 f= 1.0
# 15326999 histogram is flat 1182.0 1250.0 f= 1.0
# 15361999 histogram is flat 1992.0 2187.5 f= 1.0
# 15397999 histogram is flat 2049.0 2250.0 f= 1.0
# 15477999 histogram is flat 4552.0 5000.0 f= 1.0
# 15498999 histogram is flat 1223.0 1312.5 f= 1.0
# 15514999 histogram is flat 931.0 1000.0 f= 1.0
# 15536999 histogram is flat 1278.0 1375.0 f= 1.0
# 15570999 histogram is flat 1995.0 2125.0 f= 1.0
# 15607999 histogram is flat 2124.0 2312.5 f= 1.0
# 15656999 histogram is flat 2851.0 3062.5 f= 1.0
# 15721999 histogram is flat 3707.0 4062.5 f= 1.0
# 15732999 histogram is flat 633.0 687.5 f= 1.0
# 15775999 histogram is flat 2457.0 2687.5 f= 1.0
# 15793999 histogram is flat 1034.0 1125.0 f= 1.0
# 15825999 histogram is flat 1822.0 2000.0 f= 1.0
# 15894999 histogram is flat 3934.0 4312.5 f= 1.0
# 15911999 histogram is flat 969.0 1062.5 f= 1.0
# 15935999 histogram is flat 1366.0 1500.0 f= 1.0
# 15955999 histogram is flat 1150.0 1250.0 f= 1.0
# 15984999 histogram is flat 1650.0 1812.5 f= 1.0
# 16058999 histogram is flat 4215.0 4625.0 f= 1.0
# 16106999 histogram is flat 2732.0 3000.0 f= 1.0
# 16116999 histogram is flat 574.0 625.0 f= 1.0
# 16254999 histogram is flat 7870.0 8625.0 f= 1.0
# 16262999 histogram is flat 461.0 500.0 f= 1.0
# 16286999 histogram is flat 1370.0 1500.0 f= 1.0
# 16303999 histogram is flat 993.0 1062.5 f= 1.0
# 16331999 histogram is flat 1625.0 1750.0 f= 1.0
# 16345999 histogram is flat 808.0 875.0 f= 1.0
# 16349999 histogram is flat 230.0 250.0 f= 1.0
# 16372999 histogram is flat 1359.0 1437.5 f= 1.0
# 16416999 histogram is flat 2521.0 2750.0 f= 1.0
# 16505999 histogram is flat 5130.0 5562.5 f= 1.0
# 16519999 histogram is flat 816.0 875.0 f= 1.0
# 16537999 histogram is flat 1052.0 1125.0 f= 1.0
# 16578999 histogram is flat 2423.0 2562.5 f= 1.0
# 16631999 histogram is flat 3046.0 3312.5 f= 1.0
# 16638999 histogram is flat 419.0 437.5 f= 1.0
# 16646999 histogram is flat 462.0 500.0 f= 1.0
# 16656999 histogram is flat 570.0 625.0 f= 1.0
# 16673999 histogram is flat 983.0 1062.5 f= 1.0
# 16710999 histogram is flat 2133.0 2312.5 f= 1.0
# 16727999 histogram is flat 975.0 1062.5 f= 1.0
# 16742999 histogram is flat 854.0 937.5 f= 1.0
# 16811999 histogram is flat 3931.0 4312.5 f= 1.0
# 16897999 histogram is flat 4896.0 5375.0 f= 1.0
# 16916999 histogram is flat 1110.0 1187.5 f= 1.0
# 16937999 histogram is flat 1195.0 1312.5 f= 1.0
# 17118999 histogram is flat 10309.0 11312.5 f= 1.0
# 17137999 histogram is flat 1131.0 1187.5 f= 1.0
# 17154999 histogram is flat 971.0 1062.5 f= 1.0
# 17182999 histogram is flat 1610.0 1750.0 f= 1.0
# 17200999 histogram is flat 1035.0 1125.0 f= 1.0
# 17217999 histogram is flat 976.0 1062.5 f= 1.0
# 17266999 histogram is flat 2805.0 3062.5 f= 1.0
# 17305999 histogram is flat 2220.0 2437.5 f= 1.0
# 17369999 histogram is flat 3647.0 4000.0 f= 1.0
# 17388999 histogram is flat 1117.0 1187.5 f= 1.0
# 17413999 histogram is flat 1449.0 1562.5 f= 1.0
# 17468999 histogram is flat 3156.0 3437.5 f= 1.0
# 17544999 histogram is flat 4329.0 4750.0 f= 1.0
# 17579999 histogram is flat 2002.0 2187.5 f= 1.0
# 17603999 histogram is flat 1431.0 1500.0 f= 1.0
# 17669999 histogram is flat 3807.0 4125.0 f= 1.0
# 17687999 histogram is flat 1025.0 1125.0 f= 1.0
# 17739999 histogram is flat 2971.0 3250.0 f= 1.0
# 17770999 histogram is flat 1795.0 1937.5 f= 1.0
# 17792999 histogram is flat 1266.0 1375.0 f= 1.0
# 17882999 histogram is flat 5121.0 5625.0 f= 1.0
# 17918999 histogram is flat 2054.0 2250.0 f= 1.0
# 17980999 histogram is flat 3566.0 3875.0 f= 1.0
# 17997999 histogram is flat 1003.0 1062.5 f= 1.0
# 18017999 histogram is flat 1204.0 1250.0 f= 1.0
# 18055999 histogram is flat 2200.0 2375.0 f= 1.0
# 18095999 histogram is flat 2317.0 2500.0 f= 1.0
# 18117999 histogram is flat 1290.0 1375.0 f= 1.0
# 18132999 histogram is flat 874.0 937.5 f= 1.0
# 18151999 histogram is flat 1110.0 1187.5 f= 1.0
# 18168999 histogram is flat 1029.0 1062.5 f= 1.0
# 18206999 histogram is flat 2162.0 2375.0 f= 1.0
# 18218999 histogram is flat 713.0 750.0 f= 1.0
# 18260999 histogram is flat 2410.0 2625.0 f= 1.0
# 18280999 histogram is flat 1166.0 1250.0 f= 1.0
# 18344999 histogram is flat 3647.0 4000.0 f= 1.0
# 18364999 histogram is flat 1169.0 1250.0 f= 1.0
# 18375999 histogram is flat 638.0 687.5 f= 1.0
# 18405999 histogram is flat 1736.0 1875.0 f= 1.0
# 18499999 histogram is flat 5414.0 5875.0 f= 1.0
# 18519999 histogram is flat 1150.0 1250.0 f= 1.0
# 18547999 histogram is flat 1639.0 1750.0 f= 1.0
# 18584999 histogram is flat 2182.0 2312.5 f= 1.0
# 18681999 histogram is flat 5524.0 6062.5 f= 1.0
# 18708999 histogram is flat 1545.0 1687.5 f= 1.0
# 18720999 histogram is flat 684.0 750.0 f= 1.0
# 18745999 histogram is flat 1443.0 1562.5 f= 1.0
# 18763999 histogram is flat 1070.0 1125.0 f= 1.0
# 18777999 histogram is flat 820.0 875.0 f= 1.0
# 18949999 histogram is flat 9800.0 10750.0 f= 1.0
# 18967999 histogram is flat 1035.0 1125.0 f= 1.0
# 18989999 histogram is flat 1259.0 1375.0 f= 1.0
# 19049999 histogram is flat 3421.0 3750.0 f= 1.0
# 19085999 histogram is flat 2060.0 2250.0 f= 1.0
# 19105999 histogram is flat 1157.0 1250.0 f= 1.0
# 19112999 histogram is flat 402.0 437.5 f= 1.0
# 19124999 histogram is flat 684.0 750.0 f= 1.0
# 19154999 histogram is flat 1714.0 1875.0 f= 1.0
# 19164999 histogram is flat 570.0 625.0 f= 1.0
# 19187999 histogram is flat 1319.0 1437.5 f= 1.0
# 19214999 histogram is flat 1546.0 1687.5 f= 1.0
# 19258999 histogram is flat 2503.0 2750.0 f= 1.0
# 19401999 histogram is flat 8160.0 8937.5 f= 1.0
# 19433999 histogram is flat 1836.0 2000.0 f= 1.0
# 19453999 histogram is flat 1195.0 1250.0 f= 1.0
# 19481999 histogram is flat 1604.0 1750.0 f= 1.0
# 19501999 histogram is flat 1164.0 1250.0 f= 1.0
# 19524999 histogram is flat 1316.0 1437.5 f= 1.0
# 19539999 histogram is flat 872.0 937.5 f= 1.0
# 19603999 histogram is flat 3738.0 4000.0 f= 1.0
# 19622999 histogram is flat 1142.0 1187.5 f= 1.0
# 19650999 histogram is flat 1602.0 1750.0 f= 1.0
# 19711999 histogram is flat 3478.0 3812.5 f= 1.0
# 19726999 histogram is flat 861.0 937.5 f= 1.0
# 19744999 histogram is flat 1045.0 1125.0 f= 1.0
# 19770999 histogram is flat 1511.0 1625.0 f= 1.0
# 19817999 histogram is flat 2690.0 2937.5 f= 1.0
# 19821999 histogram is flat 230.0 250.0 f= 1.0
# 19830999 histogram is flat 520.0 562.5 f= 1.0
# 19857999 histogram is flat 1564.0 1687.5 f= 1.0
# 20010999 histogram is flat 8706.0 9562.5 f= 1.0
# 20035999 histogram is flat 1422.0 1562.5 f= 1.0
# 20066999 histogram is flat 1796.0 1937.5 f= 1.0
# 20102999 histogram is flat 2051.0 2250.0 f= 1.0
# 20181999 histogram is flat 4500.0 4937.5 f= 1.0
# 20206999 histogram is flat 1455.0 1562.5 f= 1.0
# 20331999 histogram is flat 7120.0 7812.5 f= 1.0
# 20346999 histogram is flat 857.0 937.5 f= 1.0
# 20383999 histogram is flat 2112.0 2312.5 f= 1.0
# 20398999 histogram is flat 864.0 937.5 f= 1.0
# 20412999 histogram is flat 805.0 875.0 f= 1.0
# 20554999 histogram is flat 8126.0 8875.0 f= 1.0
# 20567999 histogram is flat 741.0 812.5 f= 1.0
# 20634999 histogram is flat 3827.0 4187.5 f= 1.0
# 20648999 histogram is flat 810.0 875.0 f= 1.0
# 20694999 histogram is flat 2628.0 2875.0 f= 1.0
# 20780999 histogram is flat 4908.0 5375.0 f= 1.0
# 20795999 histogram is flat 857.0 937.5 f= 1.0
# 20827999 histogram is flat 1829.0 2000.0 f= 1.0
# 20863999 histogram is flat 2048.0 2250.0 f= 1.0
# 20895999 histogram is flat 1834.0 2000.0 f= 1.0
# 20907999 histogram is flat 693.0 750.0 f= 1.0
# 20935999 histogram is flat 1624.0 1750.0 f= 1.0
# 20970999 histogram is flat 2031.0 2187.5 f= 1.0
# 21004999 histogram is flat 1960.0 2125.0 f= 1.0
# 21024999 histogram is flat 1148.0 1250.0 f= 1.0
# 21104999 histogram is flat 4586.0 5000.0 f= 1.0
# 21122999 histogram is flat 1025.0 1125.0 f= 1.0
# 21158999 histogram is flat 2122.0 2250.0 f= 1.0
# 21173999 histogram is flat 893.0 937.5 f= 1.0
# 21393999 histogram is flat 12597.0 13750.0 f= 1.0
# 21404999 histogram is flat 629.0 687.5 f= 1.0
# 21414999 histogram is flat 584.0 625.0 f= 1.0
# 21438999 histogram is flat 1367.0 1500.0 f= 1.0
# 21446999 histogram is flat 458.0 500.0 f= 1.0
# 21479999 histogram is flat 1878.0 2062.5 f= 1.0
# 21490999 histogram is flat 659.0 687.5 f= 1.0
# 21577999 histogram is flat 5005.0 5437.5 f= 1.0
# 21692999 histogram is flat 6574.0 7187.5 f= 1.0
# 21707999 histogram is flat 866.0 937.5 f= 1.0
# 21784999 histogram is flat 4382.0 4812.5 f= 1.0
# 21811999 histogram is flat 1628.0 1687.5 f= 1.0
# 21916999 histogram is flat 5983.0 6562.5 f= 1.0
# 21943999 histogram is flat 1542.0 1687.5 f= 1.0
# 21962999 histogram is flat 1094.0 1187.5 f= 1.0
# 21978999 histogram is flat 916.0 1000.0 f= 1.0
# 21985999 histogram is flat 399.0 437.5 f= 1.0
# 21999999 histogram is flat 831.0 875.0 f= 1.0
# 22104999 histogram is flat 5986.0 6562.5 f= 1.0
# 22124999 histogram is flat 1141.0 1250.0 f= 1.0
# 22129999 histogram is flat 292.0 312.5 f= 1.0
# 22141999 histogram is flat 698.0 750.0 f= 1.0
# 22174999 histogram is flat 1898.0 2062.5 f= 1.0
# 22192999 histogram is flat 1104.0 1125.0 f= 1.0
# 22224999 histogram is flat 1844.0 2000.0 f= 1.0
# 22242999 histogram is flat 1031.0 1125.0 f= 1.0
# 22294999 histogram is flat 2964.0 3250.0 f= 1.0
# 22314999 histogram is flat 1173.0 1250.0 f= 1.0
# 22327999 histogram is flat 743.0 812.5 f= 1.0
# 22360999 histogram is flat 1884.0 2062.5 f= 1.0
# 22388999 histogram is flat 1603.0 1750.0 f= 1.0
# 22426999 histogram is flat 2181.0 2375.0 f= 1.0
# 22521999 histogram is flat 5417.0 5937.5 f= 1.0
# 22572999 histogram is flat 2931.0 3187.5 f= 1.0
# 22603999 histogram is flat 1765.0 1937.5 f= 1.0
# 22626999 histogram is flat 1323.0 1437.5 f= 1.0
# 22668999 histogram is flat 2402.0 2625.0 f= 1.0
# 22693999 histogram is flat 1422.0 1562.5 f= 1.0
# 22762999 histogram is flat 3934.0 4312.5 f= 1.0
# 22791999 histogram is flat 1652.0 1812.5 f= 1.0
# 22818999 histogram is flat 1549.0 1687.5 f= 1.0
# 22863999 histogram is flat 2636.0 2812.5 f= 1.0
# 22883999 histogram is flat 1140.0 1250.0 f= 1.0
# 22965999 histogram is flat 4735.0 5125.0 f= 1.0
# 22982999 histogram is flat 970.0 1062.5 f= 1.0
# 22990999 histogram is flat 474.0 500.0 f= 1.0
# 22996999 histogram is flat 344.0 375.0 f= 1.0
# 23020999 histogram is flat 1419.0 1500.0 f= 1.0
# 23080999 histogram is flat 3455.0 3750.0 f= 1.0
# 23103999 histogram is flat 1314.0 1437.5 f= 1.0
# 23162999 histogram is flat 3368.0 3687.5 f= 1.0
# 23166999 histogram is flat 229.0 250.0 f= 1.0
# 23200999 histogram is flat 2011.0 2125.0 f= 1.0
# 23236999 histogram is flat 2052.0 2250.0 f= 1.0
# 23276999 histogram is flat 2295.0 2500.0 f= 1.0
# 23286999 histogram is flat 572.0 625.0 f= 1.0
# 23352999 histogram is flat 3756.0 4125.0 f= 1.0
# 23370999 histogram is flat 1028.0 1125.0 f= 1.0
# 23390999 histogram is flat 1146.0 1250.0 f= 1.0
# 23404999 histogram is flat 863.0 875.0 f= 1.0
# 23427999 histogram is flat 1329.0 1437.5 f= 1.0
# 23445999 histogram is flat 1092.0 1125.0 f= 1.0
# 23482999 histogram is flat 2189.0 2312.5 f= 1.0
# 23510999 histogram is flat 1600.0 1750.0 f= 1.0
# 23522999 histogram is flat 692.0 750.0 f= 1.0
# 23580999 histogram is flat 3317.0 3625.0 f= 1.0
# 23609999 histogram is flat 1657.0 1812.5 f= 1.0
# 23623999 histogram is flat 847.0 875.0 f= 1.0
# 23634999 histogram is flat 633.0 687.5 f= 1.0
# 23666999 histogram is flat 1840.0 2000.0 f= 1.0
# 23700999 histogram is flat 1992.0 2125.0 f= 1.0
# 23717999 histogram is flat 980.0 1062.5 f= 1.0
# 23753999 histogram is flat 2119.0 2250.0 f= 1.0
# 23795999 histogram is flat 2425.0 2625.0 f= 1.0
# 23842999 histogram is flat 2703.0 2937.5 f= 1.0
# 23855999 histogram is flat 754.0 812.5 f= 1.0
# 23878999 histogram is flat 1344.0 1437.5 f= 1.0
# 23916999 histogram is flat 2189.0 2375.0 f= 1.0
# 23964999 histogram is flat 2804.0 3000.0 f= 1.0
# 23995999 histogram is flat 1766.0 1937.5 f= 1.0
# 24016999 histogram is flat 1225.0 1312.5 f= 1.0
# 24029999 histogram is flat 758.0 812.5 f= 1.0
# 24056999 histogram is flat 1552.0 1687.5 f= 1.0
# 24064999 histogram is flat 458.0 500.0 f= 1.0
# 24075999 histogram is flat 632.0 687.5 f= 1.0
# 24103999 histogram is flat 1603.0 1750.0 f= 1.0
# 24146999 histogram is flat 2479.0 2687.5 f= 1.0
# 24161999 histogram is flat 886.0 937.5 f= 1.0
# 24213999 histogram is flat 2974.0 3250.0 f= 1.0
# 24224999 histogram is flat 649.0 687.5 f= 1.0
# 24240999 histogram is flat 922.0 1000.0 f= 1.0
# 24310999 histogram is flat 3984.0 4375.0 f= 1.0
# 24325999 histogram is flat 860.0 937.5 f= 1.0
# 24368999 histogram is flat 2459.0 2687.5 f= 1.0
# 24388999 histogram is flat 1162.0 1250.0 f= 1.0
# 24406999 histogram is flat 1029.0 1125.0 f= 1.0
# 24450999 histogram is flat 2503.0 2750.0 f= 1.0
# 24471999 histogram is flat 1201.0 1312.5 f= 1.0
# 24486999 histogram is flat 883.0 937.5 f= 1.0
# 24519999 histogram is flat 1879.0 2062.5 f= 1.0
# 24550999 histogram is flat 1780.0 1937.5 f= 1.0
# 24590999 histogram is flat 2278.0 2500.0 f= 1.0
# 24603999 histogram is flat 766.0 812.5 f= 1.0
# 24638999 histogram is flat 2001.0 2187.5 f= 1.0
# 24706999 histogram is flat 3915.0 4250.0 f= 1.0
# 24719999 histogram is flat 742.0 812.5 f= 1.0
# 24734999 histogram is flat 877.0 937.5 f= 1.0
# 24752999 histogram is flat 1045.0 1125.0 f= 1.0
# 24799999 histogram is flat 2726.0 2937.5 f= 1.0
# 24956999 histogram is flat 8944.0 9812.5 f= 1.0
# 24976999 histogram is flat 1174.0 1250.0 f= 1.0
# 25037999 histogram is flat 3535.0 3812.5 f= 1.0
# 25189999 histogram is flat 8656.0 9500.0 f= 1.0
# 25232999 histogram is flat 2466.0 2687.5 f= 1.0
# 25315999 histogram is flat 4803.0 5187.5 f= 1.0
# 25345999 histogram is flat 1714.0 1875.0 f= 1.0
# 25366999 histogram is flat 1196.0 1312.5 f= 1.0
# 25580999 histogram is flat 12190.0 13375.0 f= 1.0
# 25624999 histogram is flat 2515.0 2750.0 f= 1.0
# 25638999 histogram is flat 798.0 875.0 f= 1.0
# 25652999 histogram is flat 800.0 875.0 f= 1.0
# 25685999 histogram is flat 1900.0 2062.5 f= 1.0
# 25709999 histogram is flat 1379.0 1500.0 f= 1.0
# 25734999 histogram is flat 1422.0 1562.5 f= 1.0
# 25758999 histogram is flat 1433.0 1500.0 f= 1.0
# 25795999 histogram is flat 2114.0 2312.5 f= 1.0
# 25870999 histogram is flat 4310.0 4687.5 f= 1.0
# 25950999 histogram is flat 4630.0 5000.0 f= 1.0
# 25976999 histogram is flat 1484.0 1625.0 f= 1.0
# 25991999 histogram is flat 899.0 937.5 f= 1.0
# 26196999 histogram is flat 11676.0 12812.5 f= 1.0
# 26212999 histogram is flat 914.0 1000.0 f= 1.0
# 26222999 histogram is flat 591.0 625.0 f= 1.0
# 26234999 histogram is flat 696.0 750.0 f= 1.0
# 26293999 histogram is flat 3359.0 3687.5 f= 1.0
# 26325999 histogram is flat 1829.0 2000.0 f= 1.0
# 26430999 histogram is flat 6035.0 6562.5 f= 1.0
# 26443999 histogram is flat 741.0 812.5 f= 1.0
# 26451999 histogram is flat 468.0 500.0 f= 1.0
# 26475999 histogram is flat 1370.0 1500.0 f= 1.0
# 26516999 histogram is flat 2343.0 2562.5 f= 1.0
# 26524999 histogram is flat 456.0 500.0 f= 1.0
# 26582999 histogram is flat 3313.0 3625.0 f= 1.0
# 26633999 histogram is flat 2941.0 3187.5 f= 1.0
# 26736999 histogram is flat 5912.0 6437.5 f= 1.0
# 26751999 histogram is flat 867.0 937.5 f= 1.0
# 26795999 histogram is flat 2514.0 2750.0 f= 1.0
# 26843999 histogram is flat 2731.0 3000.0 f= 1.0
# 26908999 histogram is flat 3703.0 4062.5 f= 1.0
# 26932999 histogram is flat 1418.0 1500.0 f= 1.0
# 26967999 histogram is flat 2023.0 2187.5 f= 1.0
# 27009999 histogram is flat 2412.0 2625.0 f= 1.0
# 27030999 histogram is flat 1232.0 1312.5 f= 1.0
# 27072999 histogram is flat 2448.0 2625.0 f= 1.0
# 27126999 histogram is flat 3072.0 3375.0 f= 1.0
# 27158999 histogram is flat 1824.0 2000.0 f= 1.0
# 27184999 histogram is flat 1490.0 1625.0 f= 1.0
# 27193999 histogram is flat 513.0 562.5 f= 1.0
# 27217999 histogram is flat 1411.0 1500.0 f= 1.0
# 27259999 histogram is flat 2389.0 2625.0 f= 1.0
# 27319999 histogram is flat 3427.0 3750.0 f= 1.0
# 27348999 histogram is flat 1662.0 1812.5 f= 1.0
# 27391999 histogram is flat 2475.0 2687.5 f= 1.0
# 27402999 histogram is flat 631.0 687.5 f= 1.0
# 27446999 histogram is flat 2554.0 2750.0 f= 1.0
# 27455999 histogram is flat 518.0 562.5 f= 1.0
# 27487999 histogram is flat 1890.0 2000.0 f= 1.0
# 27564999 histogram is flat 4395.0 4812.5 f= 1.0
# 27582999 histogram is flat 1062.0 1125.0 f= 1.0
# 27604999 histogram is flat 1277.0 1375.0 f= 1.0
# 27671999 histogram is flat 3873.0 4187.5 f= 1.0
# 27697999 histogram is flat 1504.0 1625.0 f= 1.0
# 27871999 histogram is flat 9921.0 10875.0 f= 1.0
# 27913999 histogram is flat 2398.0 2625.0 f= 1.0
# 28164999 histogram is flat 14324.0 15687.5 f= 1.0
# 28180999 histogram is flat 926.0 1000.0 f= 1.0
# 28193999 histogram is flat 749.0 812.5 f= 1.0
# 28232999 histogram is flat 2221.0 2437.5 f= 1.0
# 28243999 histogram is flat 641.0 687.5 f= 1.0
# 28281999 histogram is flat 2189.0 2375.0 f= 1.0
# 28299999 histogram is flat 1031.0 1125.0 f= 1.0
# 28318999 histogram is flat 1093.0 1187.5 f= 1.0
# 28354999 histogram is flat 2066.0 2250.0 f= 1.0
# 28379999 histogram is flat 1424.0 1562.5 f= 1.0
# 28403999 histogram is flat 1456.0 1500.0 f= 1.0
# 28410999 histogram is flat 406.0 437.5 f= 1.0
# 28498999 histogram is flat 5064.0 5500.0 f= 1.0
# 28521999 histogram is flat 1309.0 1437.5 f= 1.0
# 28572999 histogram is flat 2919.0 3187.5 f= 1.0
# 28598999 histogram is flat 1553.0 1625.0 f= 1.0
# 28618999 histogram is flat 1190.0 1250.0 f= 1.0
# 28649999 histogram is flat 1856.0 1937.5 f= 1.0
# 28661999 histogram is flat 705.0 750.0 f= 1.0
# 28706999 histogram is flat 2603.0 2812.5 f= 1.0
# 28850999 histogram is flat 8205.0 9000.0 f= 1.0
# 28888999 histogram is flat 2198.0 2375.0 f= 1.0
# 28941999 histogram is flat 3025.0 3312.5 f= 1.0
# 28974999 histogram is flat 1885.0 2062.5 f= 1.0
# 28992999 histogram is flat 1053.0 1125.0 f= 1.0
# 29011999 histogram is flat 1088.0 1187.5 f= 1.0
# 29054999 histogram is flat 2471.0 2687.5 f= 1.0
# 29104999 histogram is flat 2871.0 3125.0 f= 1.0
# 29116999 histogram is flat 686.0 750.0 f= 1.0
# 29147999 histogram is flat 1773.0 1937.5 f= 1.0
# 29172999 histogram is flat 1481.0 1562.5 f= 1.0
# 29182999 histogram is flat 575.0 625.0 f= 1.0
# 29234999 histogram is flat 2958.0 3250.0 f= 1.0
# 29252999 histogram is flat 1070.0 1125.0 f= 1.0
# 29263999 histogram is flat 631.0 687.5 f= 1.0
# 29286999 histogram is flat 1325.0 1437.5 f= 1.0
# 29296999 histogram is flat 570.0 625.0 f= 1.0
# 29331999 histogram is flat 1997.0 2187.5 f= 1.0
# 29350999 histogram is flat 1089.0 1187.5 f= 1.0
# 29404999 histogram is flat 3072.0 3375.0 f= 1.0
# 29424999 histogram is flat 1167.0 1250.0 f= 1.0
# 29466999 histogram is flat 2419.0 2625.0 f= 1.0
# 29497999 histogram is flat 1782.0 1937.5 f= 1.0
# 29516999 histogram is flat 1118.0 1187.5 f= 1.0
# 29561999 histogram is flat 2643.0 2812.5 f= 1.0
# 29579999 histogram is flat 1077.0 1125.0 f= 1.0
# 29607999 histogram is flat 1624.0 1750.0 f= 1.0
# 29708999 histogram is flat 5788.0 6312.5 f= 1.0
# 29733999 histogram is flat 1451.0 1562.5 f= 1.0
# 29767999 histogram is flat 2027.0 2125.0 f= 1.0
# 29782999 histogram is flat 873.0 937.5 f= 1.0
# 29792999 histogram is flat 587.0 625.0 f= 1.0
# 29840999 histogram is flat 2731.0 3000.0 f= 1.0
# 29861999 histogram is flat 1207.0 1312.5 f= 1.0
# 29908999 histogram is flat 2722.0 2937.5 f= 1.0
# 29947999 histogram is flat 2227.0 2437.5 f= 1.0
# 29972999 histogram is flat 1422.0 1562.5 f= 1.0
# 29990999 histogram is flat 1080.0 1125.0 f= 1.0
# 30043999 histogram is flat 3025.0 3312.5 f= 1.0
# 30064999 histogram is flat 1201.0 1312.5 f= 1.0
# 30101999 histogram is flat 2130.0 2312.5 f= 1.0
# 30123999 histogram is flat 1274.0 1375.0 f= 1.0
# 30173999 histogram is flat 2854.0 3125.0 f= 1.0
# 30265999 histogram is flat 5275.0 5750.0 f= 1.0
# 30277999 histogram is flat 701.0 750.0 f= 1.0
# 30303999 histogram is flat 1500.0 1625.0 f= 1.0
# 30341999 histogram is flat 2172.0 2375.0 f= 1.0
# 30363999 histogram is flat 1253.0 1375.0 f= 1.0
# 30397999 histogram is flat 1950.0 2125.0 f= 1.0
# 30511999 histogram is flat 6487.0 7125.0 f= 1.0
# 30548999 histogram is flat 2121.0 2312.5 f= 1.0
# 30584999 histogram is flat 2075.0 2250.0 f= 1.0
# 30596999 histogram is flat 693.0 750.0 f= 1.0
# 30621999 histogram is flat 1422.0 1562.5 f= 1.0
# 30633999 histogram is flat 689.0 750.0 f= 1.0
# 30742999 histogram is flat 6249.0 6812.5 f= 1.0
# 30777999 histogram is flat 2014.0 2187.5 f= 1.0
# 30802999 histogram is flat 1423.0 1562.5 f= 1.0
# 30859999 histogram is flat 3408.0 3562.5 f= 1.0
# 30872999 histogram is flat 747.0 812.5 f= 1.0
# 30916999 histogram is flat 2527.0 2750.0 f= 1.0
# 30956999 histogram is flat 2352.0 2500.0 f= 1.0
# 30970999 histogram is flat 808.0 875.0 f= 1.0
# 30997999 histogram is flat 1586.0 1687.5 f= 1.0
# 31244999 histogram is flat 14116.0 15437.5 f= 1.0
# 31258999 histogram is flat 806.0 875.0 f= 1.0
# 31321999 histogram is flat 3656.0 3937.5 f= 1.0
# 31374999 histogram is flat 3031.0 3312.5 f= 1.0
# 31415999 histogram is flat 2398.0 2562.5 f= 1.0
# 31480999 histogram is flat 3786.0 4062.5 f= 1.0
# 31543999 histogram is flat 3644.0 3937.5 f= 1.0
# 31572999 histogram is flat 1681.0 1812.5 f= 1.0
# 31587999 histogram is flat 859.0 937.5 f= 1.0
# 31616999 histogram is flat 1661.0 1812.5 f= 1.0
# 31699999 histogram is flat 4763.0 5187.5 f= 1.0
# 31716999 histogram is flat 967.0 1062.5 f= 1.0
# 31747999 histogram is flat 1778.0 1937.5 f= 1.0
# 31796999 histogram is flat 2811.0 3062.5 f= 1.0
# 32064999 histogram is flat 15244.0 16750.0 f= 1.0
# 32075999 histogram is flat 635.0 687.5 f= 1.0
# 32098999 histogram is flat 1309.0 1437.5 f= 1.0
# 32206999 histogram is flat 6146.0 6750.0 f= 1.0
# 32248999 histogram is flat 2409.0 2625.0 f= 1.0
# 32267999 histogram is flat 1084.0 1187.5 f= 1.0
# 32290999 histogram is flat 1316.0 1437.5 f= 1.0
# 32300999 histogram is flat 577.0 625.0 f= 1.0
# 32361999 histogram is flat 3475.0 3812.5 f= 1.0
# 32371999 histogram is flat 584.0 625.0 f= 1.0
# 32413999 histogram is flat 2416.0 2625.0 f= 1.0
# 32513999 histogram is flat 5723.0 6250.0 f= 1.0
# 32646999 histogram is flat 7625.0 8312.5 f= 1.0
# 32693999 histogram is flat 2678.0 2937.5 f= 1.0
# 32720999 histogram is flat 1539.0 1687.5 f= 1.0
# 32738999 histogram is flat 1033.0 1125.0 f= 1.0
# 32777999 histogram is flat 2223.0 2437.5 f= 1.0
# 32793999 histogram is flat 928.0 1000.0 f= 1.0
# 32801999 histogram is flat 459.0 500.0 f= 1.0
# 32835999 histogram is flat 1946.0 2125.0 f= 1.0
# 32855999 histogram is flat 1172.0 1250.0 f= 1.0
# 32916999 histogram is flat 3475.0 3812.5 f= 1.0
# 32937999 histogram is flat 1210.0 1312.5 f= 1.0
# 33205999 histogram is flat 15277.0 16750.0 f= 1.0
# 33236999 histogram is flat 1768.0 1937.5 f= 1.0
# 33275999 histogram is flat 2239.0 2437.5 f= 1.0
# 33300999 histogram is flat 1440.0 1562.5 f= 1.0
# 33377999 histogram is flat 4410.0 4812.5 f= 1.0
# 33436999 histogram is flat 3421.0 3687.5 f= 1.0
# 33509999 histogram is flat 4170.0 4562.5 f= 1.0
# 33531999 histogram is flat 1257.0 1375.0 f= 1.0
# 33556999 histogram is flat 1469.0 1562.5 f= 1.0
# 33588999 histogram is flat 1834.0 2000.0 f= 1.0
# 33610999 histogram is flat 1276.0 1375.0 f= 1.0
# 33629999 histogram is flat 1089.0 1187.5 f= 1.0
# 33655999 histogram is flat 1485.0 1625.0 f= 1.0
# 33712999 histogram is flat 3284.0 3562.5 f= 1.0
# 33740999 histogram is flat 1608.0 1750.0 f= 1.0
# 33749999 histogram is flat 513.0 562.5 f= 1.0
# 33759999 histogram is flat 572.0 625.0 f= 1.0
# 33818999 histogram is flat 3394.0 3687.5 f= 1.0
# 33834999 histogram is flat 918.0 1000.0 f= 1.0
# 33897999 histogram is flat 3596.0 3937.5 f= 1.0
# 33931999 histogram is flat 1988.0 2125.0 f= 1.0
# 33959999 histogram is flat 1597.0 1750.0 f= 1.0
# 34001999 histogram is flat 2441.0 2625.0 f= 1.0
# 34040999 histogram is flat 2225.0 2437.5 f= 1.0
# 34052999 histogram is flat 690.0 750.0 f= 1.0
# 34081999 histogram is flat 1661.0 1812.5 f= 1.0
# 34172999 histogram is flat 5184.0 5687.5 f= 1.0
# 34204999 histogram is flat 1847.0 2000.0 f= 1.0
# 34330999 histogram is flat 7182.0 7875.0 f= 1.0
# 34340999 histogram is flat 572.0 625.0 f= 1.0
# 34377999 histogram is flat 2105.0 2312.5 f= 1.0
# 34392999 histogram is flat 866.0 937.5 f= 1.0
# 34420999 histogram is flat 1624.0 1750.0 f= 1.0
# 34477999 histogram is flat 3285.0 3562.5 f= 1.0
# 34484999 histogram is flat 419.0 437.5 f= 1.0
# 34508999 histogram is flat 1396.0 1500.0 f= 1.0
# 34543999 histogram is flat 2015.0 2187.5 f= 1.0
# 34586999 histogram is flat 2451.0 2687.5 f= 1.0
# 34610999 histogram is flat 1373.0 1500.0 f= 1.0
# 34650999 histogram is flat 2281.0 2500.0 f= 1.0
# 34748999 histogram is flat 5592.0 6125.0 f= 1.0
# 34771999 histogram is flat 1355.0 1437.5 f= 1.0
# 34863999 histogram is flat 5355.0 5750.0 f= 1.0
# 34871999 histogram is flat 472.0 500.0 f= 1.0
# 34883999 histogram is flat 691.0 750.0 f= 1.0
# 34902999 histogram is flat 1081.0 1187.5 f= 1.0
# 34975999 histogram is flat 4186.0 4562.5 f= 1.0
# 35008999 histogram is flat 1948.0 2062.5 f= 1.0
# 35078999 histogram is flat 4005.0 4375.0 f= 1.0
# 35131999 histogram is flat 3061.0 3312.5 f= 1.0
# 35164999 histogram is flat 1890.0 2062.5 f= 1.0
# 35207999 histogram is flat 2468.0 2687.5 f= 1.0
# 35494999 histogram is flat 16510.0 17937.5 f= 1.0
# 35549999 histogram is flat 3202.0 3437.5 f= 1.0
# 35596999 histogram is flat 2709.0 2937.5 f= 1.0
# 35605999 histogram is flat 513.0 562.5 f= 1.0
# 35641999 histogram is flat 2078.0 2250.0 f= 1.0
# 35680999 histogram is flat 2253.0 2437.5 f= 1.0
# 35746999 histogram is flat 3769.0 4125.0 f= 1.0
# 35781999 histogram is flat 2022.0 2187.5 f= 1.0
# 35856999 histogram is flat 4384.0 4687.5 f= 1.0
# 35894999 histogram is flat 2190.0 2375.0 f= 1.0
# 35905999 histogram is flat 646.0 687.5 f= 1.0
# 35954999 histogram is flat 2859.0 3062.5 f= 1.0
# 36014999 histogram is flat 3457.0 3750.0 f= 1.0
# 36035999 histogram is flat 1232.0 1312.5 f= 1.0
# 36045999 histogram is flat 585.0 625.0 f= 1.0
# 36053999 histogram is flat 457.0 500.0 f= 1.0
# 36068999 histogram is flat 893.0 937.5 f= 1.0
# 36120999 histogram is flat 2967.0 3250.0 f= 1.0
# 36187999 histogram is flat 3836.0 4187.5 f= 1.0
# 36196999 histogram is flat 522.0 562.5 f= 1.0
# 36213999 histogram is flat 982.0 1062.5 f= 1.0
# 36238999 histogram is flat 1434.0 1562.5 f= 1.0
# 36252999 histogram is flat 818.0 875.0 f= 1.0
# 36271999 histogram is flat 1091.0 1187.5 f= 1.0
# 36285999 histogram is flat 802.0 875.0 f= 1.0
# 36323999 histogram is flat 2171.0 2375.0 f= 1.0
# 36341999 histogram is flat 1048.0 1125.0 f= 1.0
# 36357999 histogram is flat 913.0 1000.0 f= 1.0
# 36377999 histogram is flat 1140.0 1250.0 f= 1.0
# 36396999 histogram is flat 1106.0 1187.5 f= 1.0
# 36419999 histogram is flat 1362.0 1437.5 f= 1.0
# 36425999 histogram is flat 344.0 375.0 f= 1.0
# 36438999 histogram is flat 753.0 812.5 f= 1.0
# 36455999 histogram is flat 983.0 1062.5 f= 1.0
# 36477999 histogram is flat 1337.0 1375.0 f= 1.0
# 36488999 histogram is flat 639.0 687.5 f= 1.0
# 36538999 histogram is flat 2880.0 3125.0 f= 1.0
# 36566999 histogram is flat 1695.0 1750.0 f= 1.0
# 36580999 histogram is flat 822.0 875.0 f= 1.0
# 36596999 histogram is flat 920.0 1000.0 f= 1.0
# 36630999 histogram is flat 1952.0 2125.0 f= 1.0
# 36638999 histogram is flat 462.0 500.0 f= 1.0
# 36653999 histogram is flat 880.0 937.5 f= 1.0
# 36698999 histogram is flat 2684.0 2812.5 f= 1.0
# 36726999 histogram is flat 1612.0 1750.0 f= 1.0
# 36761999 histogram is flat 1991.0 2187.5 f= 1.0
# 36805999 histogram is flat 2504.0 2750.0 f= 1.0
# 36833999 histogram is flat 1698.0 1750.0 f= 1.0
# 36850999 histogram is flat 1012.0 1062.5 f= 1.0
# 36942999 histogram is flat 5234.0 5750.0 f= 1.0
# 36963999 histogram is flat 1238.0 1312.5 f= 1.0
# 36986999 histogram is flat 1329.0 1437.5 f= 1.0
# 37017999 histogram is flat 1765.0 1937.5 f= 1.0
# 37070999 histogram is flat 3022.0 3312.5 f= 1.0
# 37082999 histogram is flat 693.0 750.0 f= 1.0
# 37110999 histogram is flat 1596.0 1750.0 f= 1.0
# 37141999 histogram is flat 1797.0 1937.5 f= 1.0
# 37189999 histogram is flat 2743.0 3000.0 f= 1.0
# 37289999 histogram is flat 5710.0 6250.0 f= 1.0
# 37301999 histogram is flat 694.0 750.0 f= 1.0
# 37317999 histogram is flat 933.0 1000.0 f= 1.0
# 37385999 histogram is flat 3926.0 4250.0 f= 1.0
# 37418999 histogram is flat 1883.0 2062.5 f= 1.0
# 37449999 histogram is flat 1875.0 1937.5 f= 1.0
# 37617999 histogram is flat 9584.0 10500.0 f= 1.0
# 37638999 histogram is flat 1221.0 1312.5 f= 1.0
# 37731999 histogram is flat 5298.0 5812.5 f= 1.0
# 37747999 histogram is flat 926.0 1000.0 f= 1.0
# 37765999 histogram is flat 1107.0 1125.0 f= 1.0
# 37799999 histogram is flat 2017.0 2125.0 f= 1.0
# 37861999 histogram is flat 3550.0 3875.0 f= 1.0
# 37896999 histogram is flat 2007.0 2187.5 f= 1.0
# 37923999 histogram is flat 1588.0 1687.5 f= 1.0
# 37956999 histogram is flat 1920.0 2062.5 f= 1.0
# 37982999 histogram is flat 1480.0 1625.0 f= 1.0
# 38016999 histogram is flat 1976.0 2125.0 f= 1.0
# 38070999 histogram is flat 3086.0 3375.0 f= 1.0
# 38125999 histogram is flat 3133.0 3437.5 f= 1.0
# 38203999 histogram is flat 4445.0 4875.0 f= 1.0
# 38300999 histogram is flat 5524.0 6062.5 f= 1.0
# 38311999 histogram is flat 650.0 687.5 f= 1.0
# 38506999 histogram is flat 11098.0 12187.5 f= 1.0
# 38547999 histogram is flat 2347.0 2562.5 f= 1.0
# 38583999 histogram is flat 2068.0 2250.0 f= 1.0
# 38609999 histogram is flat 1518.0 1625.0 f= 1.0
# 38649999 histogram is flat 2429.0 2500.0 f= 1.0
# 38688999 histogram is flat 2277.0 2437.5 f= 1.0
# 38716999 histogram is flat 1599.0 1750.0 f= 1.0
# 38730999 histogram is flat 798.0 875.0 f= 1.0
# 38748999 histogram is flat 1049.0 1125.0 f= 1.0
# 38759999 histogram is flat 654.0 687.5 f= 1.0
# 38809999 histogram is flat 2870.0 3125.0 f= 1.0
# 38826999 histogram is flat 986.0 1062.5 f= 1.0
# 38840999 histogram is flat 803.0 875.0 f= 1.0
# 38862999 histogram is flat 1265.0 1375.0 f= 1.0
# 38888999 histogram is flat 1481.0 1625.0 f= 1.0
# 38911999 histogram is flat 1318.0 1437.5 f= 1.0
# 38917999 histogram is flat 349.0 375.0 f= 1.0
# 39179999 histogram is flat 14997.0 16375.0 f= 1.0
# 39217999 histogram is flat 2165.0 2375.0 f= 1.0
# ...
# 986257999 histogram is flat 1423.0 1562.5 f= 1.0
# 986373999 histogram is flat 6608.0 7250.0 f= 1.0
# 986392999 histogram is flat 1093.0 1187.5 f= 1.0
# 986413999 histogram is flat 1198.0 1312.5 f= 1.0
# 986454999 histogram is flat 2335.0 2562.5 f= 1.0
# 986485999 histogram is flat 1765.0 1937.5 f= 1.0
# 986499999 histogram is flat 801.0 875.0 f= 1.0
# 986512999 histogram is flat 752.0 812.5 f= 1.0
# 986545999 histogram is flat 1919.0 2062.5 f= 1.0
# 986572999 histogram is flat 1554.0 1687.5 f= 1.0
# 986609999 histogram is flat 2156.0 2312.5 f= 1.0
# 986622999 histogram is flat 747.0 812.5 f= 1.0
# 986708999 histogram is flat 4921.0 5375.0 f= 1.0
# 986721999 histogram is flat 740.0 812.5 f= 1.0
# 986743999 histogram is flat 1254.0 1375.0 f= 1.0
# 986772999 histogram is flat 1673.0 1812.5 f= 1.0
# 986790999 histogram is flat 1026.0 1125.0 f= 1.0
# 986824999 histogram is flat 1976.0 2125.0 f= 1.0
# 986942999 histogram is flat 6722.0 7375.0 f= 1.0
# 987201999 histogram is flat 14766.0 16187.5 f= 1.0
# 987220999 histogram is flat 1094.0 1187.5 f= 1.0
# 987342999 histogram is flat 6948.0 7625.0 f= 1.0
# 987365999 histogram is flat 1322.0 1437.5 f= 1.0
# 987375999 histogram is flat 569.0 625.0 f= 1.0
# 987431999 histogram is flat 3252.0 3500.0 f= 1.0
# 987448999 histogram is flat 978.0 1062.5 f= 1.0
# 987467999 histogram is flat 1092.0 1187.5 f= 1.0
# 987505999 histogram is flat 2169.0 2375.0 f= 1.0
# 987522999 histogram is flat 973.0 1062.5 f= 1.0
# 987592999 histogram is flat 4027.0 4375.0 f= 1.0
# 987617999 histogram is flat 1427.0 1562.5 f= 1.0
# 987632999 histogram is flat 869.0 937.5 f= 1.0
# 987692999 histogram is flat 3417.0 3750.0 f= 1.0
# 987732999 histogram is flat 2280.0 2500.0 f= 1.0
# 987762999 histogram is flat 1729.0 1875.0 f= 1.0
# 987809999 histogram is flat 2694.0 2937.5 f= 1.0
# 987845999 histogram is flat 2095.0 2250.0 f= 1.0
# 987891999 histogram is flat 2658.0 2875.0 f= 1.0
# 987955999 histogram is flat 3684.0 4000.0 f= 1.0
# 987968999 histogram is flat 768.0 812.5 f= 1.0
# 987983999 histogram is flat 889.0 937.5 f= 1.0
# 988023999 histogram is flat 2282.0 2500.0 f= 1.0
# 988067999 histogram is flat 2530.0 2750.0 f= 1.0
# 988086999 histogram is flat 1088.0 1187.5 f= 1.0
# 988261999 histogram is flat 9999.0 10937.5 f= 1.0
# 988286999 histogram is flat 1444.0 1562.5 f= 1.0
# 988314999 histogram is flat 1608.0 1750.0 f= 1.0
# 988369999 histogram is flat 3152.0 3437.5 f= 1.0
# 988384999 histogram is flat 859.0 937.5 f= 1.0
# 988401999 histogram is flat 992.0 1062.5 f= 1.0
# 988456999 histogram is flat 3131.0 3437.5 f= 1.0
# 988469999 histogram is flat 746.0 812.5 f= 1.0
# 988503999 histogram is flat 1981.0 2125.0 f= 1.0
# 988522999 histogram is flat 1104.0 1187.5 f= 1.0
# 988537999 histogram is flat 858.0 937.5 f= 1.0
# 988560999 histogram is flat 1319.0 1437.5 f= 1.0
# 988589999 histogram is flat 1652.0 1812.5 f= 1.0
# 988723999 histogram is flat 7713.0 8375.0 f= 1.0
# 988782999 histogram is flat 3371.0 3687.5 f= 1.0
# 988801999 histogram is flat 1088.0 1187.5 f= 1.0
# 988899999 histogram is flat 5579.0 6125.0 f= 1.0
# 988911999 histogram is flat 700.0 750.0 f= 1.0
# 988950999 histogram is flat 2257.0 2437.5 f= 1.0
# 988975999 histogram is flat 1438.0 1562.5 f= 1.0
# 989005999 histogram is flat 1711.0 1875.0 f= 1.0
# 989060999 histogram is flat 3167.0 3437.5 f= 1.0
# 989085999 histogram is flat 1442.0 1562.5 f= 1.0
# 989098999 histogram is flat 760.0 812.5 f= 1.0
# 989113999 histogram is flat 876.0 937.5 f= 1.0
# 989140999 histogram is flat 1565.0 1687.5 f= 1.0
# 989155999 histogram is flat 862.0 937.5 f= 1.0
# 989185999 histogram is flat 1721.0 1875.0 f= 1.0
# 989193999 histogram is flat 464.0 500.0 f= 1.0
# 989208999 histogram is flat 859.0 937.5 f= 1.0
# 989220999 histogram is flat 689.0 750.0 f= 1.0
# 989233999 histogram is flat 754.0 812.5 f= 1.0
# 989343999 histogram is flat 6273.0 6875.0 f= 1.0
# 989369999 histogram is flat 1521.0 1625.0 f= 1.0
# 989387999 histogram is flat 1040.0 1125.0 f= 1.0
# 989574999 histogram is flat 10723.0 11687.5 f= 1.0
# 989594999 histogram is flat 1147.0 1250.0 f= 1.0
# 989612999 histogram is flat 1032.0 1125.0 f= 1.0
# 989646999 histogram is flat 1949.0 2125.0 f= 1.0
# 989662999 histogram is flat 927.0 1000.0 f= 1.0
# 989694999 histogram is flat 1830.0 2000.0 f= 1.0
# 989793999 histogram is flat 5800.0 6187.5 f= 1.0
# 989804999 histogram is flat 653.0 687.5 f= 1.0
# 989817999 histogram is flat 751.0 812.5 f= 1.0
# 989856999 histogram is flat 2250.0 2437.5 f= 1.0
# 989879999 histogram is flat 1345.0 1437.5 f= 1.0
# 989923999 histogram is flat 2534.0 2750.0 f= 1.0
# 989951999 histogram is flat 1606.0 1750.0 f= 1.0
# 989976999 histogram is flat 1444.0 1562.5 f= 1.0
# 989997999 histogram is flat 1224.0 1312.5 f= 1.0
# 990035999 histogram is flat 2172.0 2375.0 f= 1.0
# 990053999 histogram is flat 1033.0 1125.0 f= 1.0
# 990062999 histogram is flat 512.0 562.5 f= 1.0
# 990081999 histogram is flat 1086.0 1187.5 f= 1.0
# 990089999 histogram is flat 464.0 500.0 f= 1.0
# 990114999 histogram is flat 1467.0 1562.5 f= 1.0
# 990136999 histogram is flat 1274.0 1375.0 f= 1.0
# 990142999 histogram is flat 358.0 375.0 f= 1.0
# 990168999 histogram is flat 1485.0 1625.0 f= 1.0
# 990183999 histogram is flat 865.0 937.5 f= 1.0
# 990224999 histogram is flat 2345.0 2562.5 f= 1.0
# 990252999 histogram is flat 1621.0 1750.0 f= 1.0
# 990323999 histogram is flat 4043.0 4437.5 f= 1.0
# 990373999 histogram is flat 2889.0 3125.0 f= 1.0
# 990429999 histogram is flat 3220.0 3500.0 f= 1.0
# 990496999 histogram is flat 3824.0 4187.5 f= 1.0
# 990553999 histogram is flat 3247.0 3562.5 f= 1.0
# 990573999 histogram is flat 1174.0 1250.0 f= 1.0
# 990596999 histogram is flat 1339.0 1437.5 f= 1.0
# 990607999 histogram is flat 634.0 687.5 f= 1.0
# 990800999 histogram is flat 10982.0 12062.5 f= 1.0
# 990841999 histogram is flat 2349.0 2562.5 f= 1.0
# 990875999 histogram is flat 1956.0 2125.0 f= 1.0
# 990887999 histogram is flat 692.0 750.0 f= 1.0
# 990904999 histogram is flat 973.0 1062.5 f= 1.0
# 990917999 histogram is flat 760.0 812.5 f= 1.0
# 990948999 histogram is flat 1814.0 1937.5 f= 1.0
# 990991999 histogram is flat 2451.0 2687.5 f= 1.0
# 991023999 histogram is flat 1872.0 2000.0 f= 1.0
# 991257999 histogram is flat 13318.0 14625.0 f= 1.0
# 991338999 histogram is flat 4615.0 5062.5 f= 1.0
# 991355999 histogram is flat 975.0 1062.5 f= 1.0
# 991394999 histogram is flat 2254.0 2437.5 f= 1.0
# 991404999 histogram is flat 576.0 625.0 f= 1.0
# 991520999 histogram is flat 6605.0 7250.0 f= 1.0
# 991582999 histogram is flat 3574.0 3875.0 f= 1.0
# 991645999 histogram is flat 3692.0 3937.5 f= 1.0
# 991689999 histogram is flat 2510.0 2750.0 f= 1.0
# 991704999 histogram is flat 874.0 937.5 f= 1.0
# 991721999 histogram is flat 984.0 1062.5 f= 1.0
# 991734999 histogram is flat 741.0 812.5 f= 1.0
# 991744999 histogram is flat 581.0 625.0 f= 1.0
# 991776999 histogram is flat 1864.0 2000.0 f= 1.0
# 991793999 histogram is flat 988.0 1062.5 f= 1.0
# 991839999 histogram is flat 2659.0 2875.0 f= 1.0
# 991877999 histogram is flat 2179.0 2375.0 f= 1.0
# 992015999 histogram is flat 7867.0 8625.0 f= 1.0
# 992025999 histogram is flat 570.0 625.0 f= 1.0
# 992050999 histogram is flat 1481.0 1562.5 f= 1.0
# 992100999 histogram is flat 2859.0 3125.0 f= 1.0
# 992225999 histogram is flat 7144.0 7812.5 f= 1.0
# 992253999 histogram is flat 1599.0 1750.0 f= 1.0
# 992266999 histogram is flat 760.0 812.5 f= 1.0
# 992307999 histogram is flat 2332.0 2562.5 f= 1.0
# 992348999 histogram is flat 2355.0 2562.5 f= 1.0
# 992381999 histogram is flat 1904.0 2062.5 f= 1.0
# 992421999 histogram is flat 2298.0 2500.0 f= 1.0
# 992433999 histogram is flat 707.0 750.0 f= 1.0
# 992450999 histogram is flat 991.0 1062.5 f= 1.0
# 992490999 histogram is flat 2286.0 2500.0 f= 1.0
# 992511999 histogram is flat 1226.0 1312.5 f= 1.0
# 992519999 histogram is flat 460.0 500.0 f= 1.0
# 992563999 histogram is flat 2541.0 2750.0 f= 1.0
# 992598999 histogram is flat 2001.0 2187.5 f= 1.0
# 992635999 histogram is flat 2146.0 2312.5 f= 1.0
# 992661999 histogram is flat 1506.0 1625.0 f= 1.0
# 992675999 histogram is flat 797.0 875.0 f= 1.0
# 993189999 histogram is flat 29312.0 32125.0 f= 1.0
# 993243999 histogram is flat 3073.0 3375.0 f= 1.0
# 993258999 histogram is flat 865.0 937.5 f= 1.0
# 993288999 histogram is flat 1723.0 1875.0 f= 1.0
# 993331999 histogram is flat 2446.0 2687.5 f= 1.0
# 993346999 histogram is flat 867.0 937.5 f= 1.0
# 993365999 histogram is flat 1081.0 1187.5 f= 1.0
# 993578999 histogram is flat 12120.0 13312.5 f= 1.0
# 993615999 histogram is flat 2112.0 2312.5 f= 1.0
# 993643999 histogram is flat 1605.0 1750.0 f= 1.0
# 993657999 histogram is flat 801.0 875.0 f= 1.0
# 993768999 histogram is flat 6327.0 6937.5 f= 1.0
# 993794999 histogram is flat 1517.0 1625.0 f= 1.0
# 993814999 histogram is flat 1160.0 1250.0 f= 1.0
# 993855999 histogram is flat 2355.0 2562.5 f= 1.0
# 993969999 histogram is flat 6493.0 7125.0 f= 1.0
# 993985999 histogram is flat 929.0 1000.0 f= 1.0
# 994015999 histogram is flat 1722.0 1875.0 f= 1.0
# 994052999 histogram is flat 2133.0 2312.5 f= 1.0
# 994060999 histogram is flat 473.0 500.0 f= 1.0
# 994080999 histogram is flat 1145.0 1250.0 f= 1.0
# 994125999 histogram is flat 2568.0 2812.5 f= 1.0
# 994159999 histogram is flat 2014.0 2125.0 f= 1.0
# 994175999 histogram is flat 911.0 1000.0 f= 1.0
# 994201999 histogram is flat 1505.0 1625.0 f= 1.0
# 994214999 histogram is flat 750.0 812.5 f= 1.0
# 994246999 histogram is flat 1832.0 2000.0 f= 1.0
# 994287999 histogram is flat 2336.0 2562.5 f= 1.0
# 994308999 histogram is flat 1219.0 1312.5 f= 1.0
# 994321999 histogram is flat 752.0 812.5 f= 1.0
# 994421999 histogram is flat 5715.0 6250.0 f= 1.0
# 994469999 histogram is flat 2741.0 3000.0 f= 1.0
# 994488999 histogram is flat 1089.0 1187.5 f= 1.0
# 994520999 histogram is flat 1859.0 2000.0 f= 1.0
# 994553999 histogram is flat 1942.0 2062.5 f= 1.0
# 994563999 histogram is flat 574.0 625.0 f= 1.0
# 994592999 histogram is flat 1708.0 1812.5 f= 1.0
# 994633999 histogram is flat 2339.0 2562.5 f= 1.0
# 994658999 histogram is flat 1447.0 1562.5 f= 1.0
# 994667999 histogram is flat 530.0 562.5 f= 1.0
# 994687999 histogram is flat 1187.0 1250.0 f= 1.0
# 994715999 histogram is flat 1605.0 1750.0 f= 1.0
# 994731999 histogram is flat 918.0 1000.0 f= 1.0
# 994799999 histogram is flat 3896.0 4250.0 f= 1.0
# 994837999 histogram is flat 2257.0 2375.0 f= 1.0
# 994850999 histogram is flat 766.0 812.5 f= 1.0
# 994862999 histogram is flat 686.0 750.0 f= 1.0
# 994870999 histogram is flat 462.0 500.0 f= 1.0
# 994884999 histogram is flat 799.0 875.0 f= 1.0
# 994917999 histogram is flat 1912.0 2062.5 f= 1.0
# 995267999 histogram is flat 19923.0 21875.0 f= 1.0
# 995299999 histogram is flat 1867.0 2000.0 f= 1.0
# 995345999 histogram is flat 2655.0 2875.0 f= 1.0
# 995424999 histogram is flat 4514.0 4937.5 f= 1.0
# 995442999 histogram is flat 1032.0 1125.0 f= 1.0
# 995461999 histogram is flat 1113.0 1187.5 f= 1.0
# 995491999 histogram is flat 1726.0 1875.0 f= 1.0
# 995569999 histogram is flat 4496.0 4875.0 f= 1.0
# 995628999 histogram is flat 3376.0 3687.5 f= 1.0
# 995756999 histogram is flat 7298.0 8000.0 f= 1.0
# 995776999 histogram is flat 1153.0 1250.0 f= 1.0
# 995799999 histogram is flat 1311.0 1437.5 f= 1.0
# 995809999 histogram is flat 573.0 625.0 f= 1.0
# 995829999 histogram is flat 1156.0 1250.0 f= 1.0
# 995841999 histogram is flat 690.0 750.0 f= 1.0
# 995918999 histogram is flat 4494.0 4812.5 f= 1.0
# 995943999 histogram is flat 1422.0 1562.5 f= 1.0
# 996025999 histogram is flat 4730.0 5125.0 f= 1.0
# 996067999 histogram is flat 2395.0 2625.0 f= 1.0
# 996099999 histogram is flat 1859.0 2000.0 f= 1.0
# 996157999 histogram is flat 3320.0 3625.0 f= 1.0
# 996228999 histogram is flat 4040.0 4437.5 f= 1.0
# 996286999 histogram is flat 3352.0 3625.0 f= 1.0
# 996335999 histogram is flat 2905.0 3062.5 f= 1.0
# 996361999 histogram is flat 1508.0 1625.0 f= 1.0
# 996390999 histogram is flat 1692.0 1812.5 f= 1.0
# 996447999 histogram is flat 3246.0 3562.5 f= 1.0
# 996466999 histogram is flat 1081.0 1187.5 f= 1.0
# 996477999 histogram is flat 626.0 687.5 f= 1.0
# 996533999 histogram is flat 3310.0 3500.0 f= 1.0
# 996584999 histogram is flat 2911.0 3187.5 f= 1.0
# 996599999 histogram is flat 859.0 937.5 f= 1.0
# 996613999 histogram is flat 815.0 875.0 f= 1.0
# 996631999 histogram is flat 1035.0 1125.0 f= 1.0
# 996651999 histogram is flat 1151.0 1250.0 f= 1.0
# 996662999 histogram is flat 634.0 687.5 f= 1.0
# 996680999 histogram is flat 1028.0 1125.0 f= 1.0
# 996695999 histogram is flat 858.0 937.5 f= 1.0
# 996772999 histogram is flat 4426.0 4812.5 f= 1.0
# 996817999 histogram is flat 2572.0 2812.5 f= 1.0
# 996926999 histogram is flat 6252.0 6812.5 f= 1.0
# 997012999 histogram is flat 4894.0 5375.0 f= 1.0
# 997087999 histogram is flat 4275.0 4687.5 f= 1.0
# 997158999 histogram is flat 4078.0 4437.5 f= 1.0
# 997169999 histogram is flat 630.0 687.5 f= 1.0
# 997205999 histogram is flat 2129.0 2250.0 f= 1.0
# 997236999 histogram is flat 1769.0 1937.5 f= 1.0
# 997251999 histogram is flat 860.0 937.5 f= 1.0
# 997264999 histogram is flat 740.0 812.5 f= 1.0
# 997298999 histogram is flat 1971.0 2125.0 f= 1.0
# 997328999 histogram is flat 1707.0 1875.0 f= 1.0
# 997353999 histogram is flat 1457.0 1562.5 f= 1.0
# 997446999 histogram is flat 5339.0 5812.5 f= 1.0
# 997493999 histogram is flat 2694.0 2937.5 f= 1.0
# 997518999 histogram is flat 1431.0 1562.5 f= 1.0
# 997558999 histogram is flat 2325.0 2500.0 f= 1.0
# 997567999 histogram is flat 512.0 562.5 f= 1.0
# 997608999 histogram is flat 2351.0 2562.5 f= 1.0
# 997622999 histogram is flat 844.0 875.0 f= 1.0
# 997643999 histogram is flat 1244.0 1312.5 f= 1.0
# 997692999 histogram is flat 2818.0 3062.5 f= 1.0
# 997750999 histogram is flat 3312.0 3625.0 f= 1.0
# 997777999 histogram is flat 1573.0 1687.5 f= 1.0
# 997812999 histogram is flat 2019.0 2187.5 f= 1.0
# 997953999 histogram is flat 8086.0 8812.5 f= 1.0
# 997982999 histogram is flat 1668.0 1812.5 f= 1.0
# 997999999 histogram is flat 975.0 1062.5 f= 1.0
# 998047999 histogram is flat 2753.0 3000.0 f= 1.0
# 998072999 histogram is flat 1518.0 1562.5 f= 1.0
# 998092999 histogram is flat 1163.0 1250.0 f= 1.0
# 998117999 histogram is flat 1486.0 1562.5 f= 1.0
# 998123999 histogram is flat 347.0 375.0 f= 1.0
# 998160999 histogram is flat 2164.0 2312.5 f= 1.0
# 998174999 histogram is flat 819.0 875.0 f= 1.0
# 998225999 histogram is flat 2914.0 3187.5 f= 1.0
# 998239999 histogram is flat 814.0 875.0 f= 1.0
# 998256999 histogram is flat 972.0 1062.5 f= 1.0
# 998285999 histogram is flat 1681.0 1812.5 f= 1.0
# 998307999 histogram is flat 1259.0 1375.0 f= 1.0
# 998327999 histogram is flat 1140.0 1250.0 f= 1.0
# 998411999 histogram is flat 4815.0 5250.0 f= 1.0
# 998497999 histogram is flat 4906.0 5375.0 f= 1.0
# 998518999 histogram is flat 1240.0 1312.5 f= 1.0
# 998547999 histogram is flat 1671.0 1812.5 f= 1.0
# 998623999 histogram is flat 4331.0 4750.0 f= 1.0
# 998646999 histogram is flat 1359.0 1437.5 f= 1.0
# 998663999 histogram is flat 995.0 1062.5 f= 1.0
# 998844999 histogram is flat 10348.0 11312.5 f= 1.0
# 998855999 histogram is flat 647.0 687.5 f= 1.0
# 998875999 histogram is flat 1138.0 1250.0 f= 1.0
# 998890999 histogram is flat 888.0 937.5 f= 1.0
# 999009999 histogram is flat 6788.0 7437.5 f= 1.0
# 999036999 histogram is flat 1561.0 1687.5 f= 1.0
# 999058999 histogram is flat 1259.0 1375.0 f= 1.0
# 999098999 histogram is flat 2278.0 2500.0 f= 1.0
# 999114999 histogram is flat 940.0 1000.0 f= 1.0
# 999144999 histogram is flat 1722.0 1875.0 f= 1.0
# 999170999 histogram is flat 1529.0 1625.0 f= 1.0
# 999195999 histogram is flat 1423.0 1562.5 f= 1.0
# 999219999 histogram is flat 1381.0 1500.0 f= 1.0
# 999319999 histogram is flat 5700.0 6250.0 f= 1.0
# 999338999 histogram is flat 1111.0 1187.5 f= 1.0
# 999521999 histogram is flat 10463.0 11437.5 f= 1.0
# 999567999 histogram is flat 2633.0 2875.0 f= 1.0
# 999609999 histogram is flat 2431.0 2625.0 f= 1.0
# 999643999 histogram is flat 1951.0 2125.0 f= 1.0
# 999664999 histogram is flat 1241.0 1312.5 f= 1.0
# 999703999 histogram is flat 2228.0 2437.5 f= 1.0
# 999720999 histogram is flat 978.0 1062.5 f= 1.0
# 999777999 histogram is flat 3276.0 3562.5 f= 1.0
# 999819999 histogram is flat 2402.0 2625.0 f= 1.0
# 999840999 histogram is flat 1226.0 1312.5 f= 1.0
# 999876999 histogram is flat 2053.0 2250.0 f= 1.0
# 999882999 histogram is flat 343.0 375.0 f= 1.0
# 999898999 histogram is flat 914.0 1000.0 f= 1.0
# 999925999 histogram is flat 1543.0 1687.5 f= 1.0
# 999953999 histogram is flat 1597.0 1750.0 f= 1.0
# 999978999 histogram is flat 1448.0 1562.5 f= 1.0
# Done

# %%
lngE[0],lngE[-1]
# Out:
# (np.float64(617.4336755551699), np.float64(617.2640183139074))

# %%
# Proper normalization of the Density of states
# g *= 4/(g[0]+g[-1]) = 4/(g[-1]*(1+g[0]/g[-1]))
# g = g * 4/(g[-1]*(1+g[0]/g[-1]))
# log(g) = log(g) + log(4)-log(g[-1]) - log(1+g[0]/g[-1])
# log(g) += log(4)-log(g[-1])-log(1+exp(log(g[0])-log(g[-1])))
# 
if lngE[-1]>lngE[0]:
    lgC = log(4)-lngE[-1]-log(1+exp(lngE[0]-lngE[-1]))
else:
    lgC = log(4)-lngE[0]-log(1+exp(lngE[-1]-lngE[0]))

lngE += lgC

# %%
exp(lngE[0])+exp(lngE[-1]), exp(lngE[0]), exp(lngE[-1])  # g[0]+g[-1]
# Out:
# (np.float64(4.000000000000155),
#  np.float64(2.169251463970372),
#  np.float64(1.8307485360297837))

# %%
print(Energies)
plt.figure(figsize=(7,5))
plt.plot(Energies, lngE)
plt.xlabel("Energy $E$")
plt.ylabel("log Density of States $\\ln g(E)$")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [-32 -24 -20 -16 -12  -8  -4   0   4   8  12  16  20  24  32]

# %% [markdown]
# #### Parition function:
# $Z = \sum_{E} g[E] e^{-E/T}$

# %%
print(len(Energies), len(lngE))
# Out:
# 15 15

# %%
import numpy as np
def partition_function(Energies, lngE, T):
    """
    Compute partition function Z(T) from Wang-Landau output.
    Args:
        Energies: array of energy values
        lngE: array of ln(g(E)) values
        T: temperature or array of temperatures
    Returns:
        Z: partition function(s) at given temperature(s)
    """
    Energies = np.array(Energies)
    lngE = np.array(lngE)
    if np.isscalar(T):
        Z = np.sum(np.exp(lngE - Energies / T))
        return Z
    else:
        Zs = []
        for temp in T:
            Zs.append(np.sum(np.exp(lngE - Energies / temp)))
        return np.array(Zs)

Tc = 2.269
delta = 1.5

Te = np.linspace(Tc - delta, Tc + delta, 5)
Z = []
for T in Te:
    Z.append(partition_function(Energies, lngE,T))
Z = array(Z)

# %%
plt.plot(Te, Z, label='Partition Function')
plt.xlabel('T')
plt.legend(loc='best')
plt.show()

# %%
print(Z)
# Out:
# [2.56214344e+18 3.38098329e+09 6.03130588e+06 6.11622789e+05
#  2.49008562e+05]

# %%
import numpy as np
import math
import random as r
from numba import jit
import itertools
import matplotlib.pyplot as plt

k_B = 1  # Boltzmann constant

def enumerate_partition_function(N, T):
    """
    Brute force enumeration to compute Z(T).
    """
    n_sites = N*N
    Z = 0.0
    for spins in itertools.product([-1, 1], repeat=n_sites):
        # Convert spins tuple to N x N lattice
        latt = np.array(spins).reshape((N, N))
        E = CEnergy(latt, N)
        Z += math.exp(-E / (k_B * T))
    return Z



sign = lambda x : math.copysign(1, x)

@jit(nopython=True)
def CEnergy(latt, N):
    Ene = 0
    for i in range(N):
        for j in range(N):
            S = latt[i,j]
            WF = latt[i, (j+1)%N] + latt[i, (j-1)%N] + latt[(i+1)%N, j] + latt[(i-1)%N, j]
            Ene += -S*WF
    return int(Ene/2)

def RandomL(N):
    latt = np.zeros((N,N), dtype=int)
    for i in range(N):
        for j in range(N):
            latt[i,j] = sign(2*r.random() - 1)
    return latt


N = 4  
Te = np.linspace(Tc - delta, Tc + delta, 5)
Z_exact = []
print(f"Enumerating all {2**(N*N):,} configurations for N={N} ...")
for T in Te:
    Z_exact.append(enumerate_partition_function(N, T))
Z_exact = np.array(Z_exact)
print(Z_exact)
# Out:
# Enumerating all 65,536 configurations for N=4 ...
# [2.36219219e+18 3.10728353e+09 5.51408947e+06 5.66417185e+05
#  2.33754580e+05]

# %%
squared_errors = (Z - Z_exact) ** 2
print("Squared errors:", squared_errors)
plt.plot(Te, Z, label='Wang-Landau Z(T)')
plt.plot(Te, Z_exact, label='Exact Enumeration Z(T)', linestyle='--')
plt.xlabel('Temperature T')
plt.ylabel('Partition Function Z(T)')
plt.legend(loc='best')
plt.show()
# Out:
# Squared errors: [7.22323781e+32 2.84182742e+14 1.26873674e+09 8.49322433e+06
#  1.54242414e+07]
